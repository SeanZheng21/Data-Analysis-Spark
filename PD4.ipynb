# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/"> <img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-nd/4.0/88x31.png"/> </a>This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/"> Creative Commons Attribution-NonCommercial-NoDerivatives 4.0 International License. </a>

# %% [markdown]
# # PD4: Predicting Movie Rating
# ## MTI850 - Big Data Analytics
# ### Fall 2020

# %% [markdown]
# <br>
# <br>
#
# | Étudiant | Xiaoang Zheng ZHEX21029701                                   |
# |----------|---------------------------------------------------------|
#
# <br>
# <br>

# %% [markdown]
# ![Spark Logo](http://alekoe.github.io/images/ta_Spark-logo-small.png) ![Python Logo](http://alekoe.github.io/images/python-logo-master-v3-TM-flattened_small.png)
#
# One of the most common uses of big data is to predict what users want.  This allows Google to show you relevant ads, Amazon to recommend relevant products, and Netflix to recommend movies that you might like. In this assignment you will use Apache Spark to recommend movies to a user. You will start with some basic techniques, and then use the [Spark ML](https://spark.apache.org/docs/latest/api/python/pyspark.ml.html) library's Alternating Least Squares method to make more sophisticated predictions.
#
# For this assignment, you will use the [MovieLens 20M Dataset](http://grouplens.org/datasets/movielens/), which comprises 20 million movie rantings. Download and prepare the dataset by running the following commands in a terminal shell:
# ```
# wget http://files.grouplens.org/datasets/movielens/ml-20m.zip
# unzip ml-20m.zip
# hdfs dfs -put ml-20m /ml-20m
# ```
#
# In this lab:
# * *Part 0*: Preliminaries
# * *Part 1*: Basic Recommendations
# * *Part 2*: Collaborative Filtering
# * *Part 3*: Predictions for Yourself
#
# As mentioned during the classes, think carefully before calling `collect()` on any datasets.  When you are using a small dataset, calling `collect()` and then using Python to get a sense for the data locally (in the driver program) will work fine, but this will not work when you are using a large dataset that doesn't fit in memory on one machine.

# %% [markdown]
# ## Code
#
# This assignment can be completed using basic Python and pySpark DataFrame Transformations and Actions.  Libraries other than math are not necessary. With the exception of the ML functions that we introduce in this assignment, you should be able to complete all parts of this homework using only the Spark functions you have used in prior lab exercises (although you are welcome to use more features of Spark if you like!).
#
#
# The following cell defines the locations of the data files and prepare the application enviromnent we are used to.
#
# **To Do**: Run the following cell.

# %%
import os
import findspark
findspark.init()

# Test module for MTI850
import testmti850

# Util module for MTI850
# Download and use the updated version of utilmti850 module
import utilmti850

import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
.master("local") \
.appName("Predicting Movie Ratings Application") \
.config("spark.some.config.option", "some-value") \
.getOrCreate()

# dataset location
hdfs_dir = 'ml-20m'
ratings_filename = hdfs_dir + '/ratings.csv'
movies_filename = hdfs_dir + '/movies.csv'

# The following line is here to enable this notebook to be exported as source and
# run on a local machine with a local copy of the files. Just change the dbfs_dir,
# above.
if os.path.sep != '/':
    # Handle Windows.
    ratings_filename = ratings_filename.replace('/', os.path.sep)
    movie_filename = movie_filename.replace('/', os.path.sep)

# %% [markdown]
# ## Part 0: Preliminaries
#
# We read in each of the files and create a DataFrame consisting of parsed lines.
#
# ### The 20-million movie sample
#
# The 20-million movie sample consists of CSV files (with headers), so there's no need to parse the files manually, as Spark CSV can do the job.
#
# First, let's take a look at the directory containing our files.

# %%
from utilmti850 import listHDFSDir

listHDFSDir(os.path.sep + hdfs_dir)
# Out:
# Found 7 items
# -rw-r--r--   1 carlistle supergroup     10.0 K 2020-10-28 18:40 /ml-20m/README.txt
# -rw-r--r--   1 carlistle supergroup    308.6 M 2020-10-28 18:40 /ml-20m/genome-scores.csv
# -rw-r--r--   1 carlistle supergroup     17.7 K 2020-10-28 18:40 /ml-20m/genome-tags.csv
# -rw-r--r--   1 carlistle supergroup    556.7 K 2020-10-28 18:40 /ml-20m/links.csv
# -rw-r--r--   1 carlistle supergroup      1.3 M 2020-10-28 18:40 /ml-20m/movies.csv
# -rw-r--r--   1 carlistle supergroup    508.7 M 2020-10-28 18:40 /ml-20m/ratings.csv
# -rw-r--r--   1 carlistle supergroup     15.8 M 2020-10-28 18:40 /ml-20m/tags.csv

# %% [markdown]
# ### Schema
#
# We're going to speed things up by specifying the DataFrame schema explicitly. When the Spark CSV adapter infers the schema from a CSV file, it has to make an extra pass over the file. That'll slow things down here, and it isn't really necessary.
#
# **To Do**: Run the following cell, which will define the schemas.

# %%
from pyspark.sql.types import *

ratings_df_schema = StructType(
  [StructField('userId', IntegerType()),
   StructField('movieId', IntegerType()),
   StructField('rating', DoubleType())]
)
movies_df_schema = StructType(
  [StructField('ID', IntegerType()),
   StructField('title', StringType())]
)

# %% [markdown]
# ### Load and Cache
#
# Rather than read data over and over again, the movies DataFrame and the ratings DataFrame will be cached in memory to maximize performance.
#
# **To Do**: Run the following cell to load and cache the data. Please be patient: The code takes about 30 seconds to run.

# %%
from pyspark.sql.functions import regexp_extract
from pyspark.sql.types import *


raw_ratings_df = spark.read.csv(ratings_filename, schema=ratings_df_schema, header=True)
ratings_df = raw_ratings_df.drop('Timestamp')

raw_movies_df = spark.read.csv(movies_filename, schema=movies_df_schema, header=True)
movies_df = raw_movies_df.drop('Genres').withColumnRenamed('movieId', 'ID')

ratings_df.cache()
movies_df.cache()

assert ratings_df.is_cached
assert movies_df.is_cached

raw_ratings_count = raw_ratings_df.count()
ratings_count = ratings_df.count()
raw_movies_count = raw_movies_df.count()
movies_count = movies_df.count()

print ('There are %s ratings and %s movies in the datasets' % (ratings_count, movies_count))
print ('Ratings:')
ratings_df.show(3)
print ('Movies:')
movies_df.show(3, truncate=False)

assert raw_ratings_count == ratings_count
assert raw_movies_count == movies_count
# Out:
# There are 20000263 ratings and 27278 movies in the datasets
# Ratings:
# +------+-------+------+
# |userId|movieId|rating|
# +------+-------+------+
# |     1|      2|   3.5|
# |     1|     29|   3.5|
# |     1|     32|   3.5|
# +------+-------+------+
# only showing top 3 rows
#
# Movies:
# +---+-----------------------+
# |ID |title                  |
# +---+-----------------------+
# |1  |Toy Story (1995)       |
# |2  |Jumanji (1995)         |
# |3  |Grumpier Old Men (1995)|
# +---+-----------------------+
# only showing top 3 rows

# %% [markdown]
# Next, let's do a quick verification of the data.
#
# **To do**: Run the following cell. It should run without errors.

# %%
assert ratings_count == 20000263
assert movies_count == 27278
assert movies_df.filter(movies_df.title == 'Toy Story (1995)').count() == 1
assert ratings_df.filter((ratings_df.userId == 6) & (ratings_df.movieId == 1) & (ratings_df.rating == 5.0)).count() == 1

# %% [markdown]
# Let's take a quick look at some of the data in the two DataFrames.
#
# **To Do**: Run the following two cells.

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

movies_df.limit(1000).toPandas() # convert into a Pandas DataFrame and display
# Out:
#        ID                                              title
# 0       1                                   Toy Story (1995)
# 1       2                                     Jumanji (1995)
# 2       3                            Grumpier Old Men (1995)
# 3       4                           Waiting to Exhale (1995)
# 4       5                 Father of the Bride Part II (1995)
# 5       6                                        Heat (1995)
# 6       7                                     Sabrina (1995)
# 7       8                                Tom and Huck (1995)
# 8       9                                Sudden Death (1995)
# 9      10                                   GoldenEye (1995)
# 10     11                     American President, The (1995)
# 11     12                 Dracula: Dead and Loving It (1995)
# 12     13                                       Balto (1995)
# 13     14                                       Nixon (1995)
# 14     15                            Cutthroat Island (1995)
# 15     16                                      Casino (1995)
# 16     17                       Sense and Sensibility (1995)
# 17     18                                  Four Rooms (1995)
# 18     19              Ace Ventura: When Nature Calls (1995)
# 19     20                                 Money Train (1995)
# 20     21                                  Get Shorty (1995)
# 21     22                                     Copycat (1995)
# 22     23                                   Assassins (1995)
# 23     24                                      Powder (1995)
# 24     25                           Leaving Las Vegas (1995)
# 25     26                                     Othello (1995)
# 26     27                                Now and Then (1995)
# 27     28                                  Persuasion (1995)
# 28     29  City of Lost Children, The (Cité des enfants p...
# 29     30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 30     31                             Dangerous Minds (1995)
# 31     32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 32     33                            Wings of Courage (1995)
# 33     34                                        Babe (1995)
# 34     35                                  Carrington (1995)
# 35     36                            Dead Man Walking (1995)
# 36     37                      Across the Sea of Time (1995)
# 37     38                                It Takes Two (1995)
# 38     39                                    Clueless (1995)
# 39     40                    Cry, the Beloved Country (1995)
# 40     41                                 Richard III (1995)
# 41     42                             Dead Presidents (1995)
# 42     43                                 Restoration (1995)
# 43     44                               Mortal Kombat (1995)
# 44     45                                  To Die For (1995)
# 45     46               How to Make an American Quilt (1995)
# 46     47                        Seven (a.k.a. Se7en) (1995)
# 47     48                                  Pocahontas (1995)
# 48     49                       When Night Is Falling (1995)
# 49     50                         Usual Suspects, The (1995)
# 50     51                              Guardian Angel (1994)
# 51     52                            Mighty Aphrodite (1995)
# 52     53                                    Lamerica (1994)
# 53     54                              Big Green, The (1995)
# 54     55                                     Georgia (1995)
# 55     56                     Kids of the Round Table (1995)
# 56     57                       Home for the Holidays (1995)
# 57     58                  Postman, The (Postino, Il) (1994)
# 58     59       Confessional, The (Confessionnal, Le) (1995)
# 59     60                 Indian in the Cupboard, The (1995)
# 60     61                              Eye for an Eye (1996)
# 61     62                          Mr. Holland's Opus (1995)
# 62     63  Don't Be a Menace to South Central While Drink...
# 63     64                               Two if by Sea (1996)
# 64     65                                    Bio-Dome (1996)
# 65     66          Lawnmower Man 2: Beyond Cyberspace (1996)
# 66     67                                    Two Bits (1995)
# 67     68                 French Twist (Gazon maudit) (1995)
# 68     69                                      Friday (1995)
# 69     70                         From Dusk Till Dawn (1996)
# 70     71                                   Fair Game (1995)
# 71     72                       Kicking and Screaming (1995)
# 72     73                             Misérables, Les (1995)
# 73     74                                Bed of Roses (1996)
# 74     75                                   Big Bully (1996)
# 75     76                                   Screamers (1995)
# 76     77                                   Nico Icon (1995)
# 77     78                         Crossing Guard, The (1995)
# 78     79                                  Juror, The (1996)
# 79     80        White Balloon, The (Badkonake sefid) (1995)
# 80     81     Things to Do in Denver When You're Dead (1995)
# 81     82                    Antonia's Line (Antonia) (1995)
# 82     83    Once Upon a Time... When We Were Colored (1995)
# 83     84                 Last Summer in the Hamptons (1995)
# 84     85                          Angels and Insects (1995)
# 85     86                                White Squall (1996)
# 86     87                           Dunston Checks In (1996)
# 87     88                                 Black Sheep (1996)
# 88     89                                Nick of Time (1995)
# 89     90                 Journey of August King, The (1995)
# 90     92                                 Mary Reilly (1996)
# 91     93                         Vampire in Brooklyn (1995)
# 92     94                             Beautiful Girls (1996)
# 93     95                                Broken Arrow (1996)
# 94     96                      In the Bleak Midwinter (1995)
# 95     97                            Hate (Haine, La) (1995)
# 96     98                                    Shopping (1994)
# 97     99               Heidi Fleiss: Hollywood Madam (1995)
# 98    100                                   City Hall (1996)
# 99    101                               Bottle Rocket (1996)
# 100   102                                   Mr. Wrong (1996)
# 101   103                               Unforgettable (1996)
# 102   104                               Happy Gilmore (1996)
# 103   105              Bridges of Madison County, The (1995)
# 104   106         Nobody Loves Me (Keiner liebt mich) (1994)
# 105   107                      Muppet Treasure Island (1996)
# 106   108                                     Catwalk (1996)
# 107   109                Headless Body in Topless Bar (1995)
# 108   110                                  Braveheart (1995)
# 109   111                                 Taxi Driver (1976)
# 110   112         Rumble in the Bronx (Hont faan kui) (1995)
# 111   113                            Before and After (1996)
# 112   114                           Margaret's Museum (1995)
# 113   115  Happiness Is in the Field (Bonheur est dans le...
# 114   116                       Anne Frank Remembered (1995)
# 115   117              Young Poisoner's Handbook, The (1995)
# 116   118                                If Lucy Fell (1996)
# 117   119                     Steal Big, Steal Little (1995)
# 118   120                                Race the Sun (1996)
# 119   121                    Boys of St. Vincent, The (1992)
# 120   122                                   Boomerang (1992)
# 121   123      Chungking Express (Chung Hing sam lam) (1994)
# 122   124     Star Maker, The (Uomo delle stelle, L') (1995)
# 123   125                      Flirting With Disaster (1996)
# 124   126                  NeverEnding Story III, The (1994)
# 125   127  Silences of the Palace, The (Saimt el Qusur) (...
# 126   128                              Jupiter's Wife (1994)
# 127   129                              Pie in the Sky (1996)
# 128   130                                      Angela (1995)
# 129   131                           Frankie Starlight (1995)
# 130   132                                        Jade (1995)
# 131   133                                   Nueba Yol (1995)
# 132   134                               Sonic Outlaws (1995)
# 133   135                              Down Periscope (1996)
# 134   136            From the Journals of Jean Seberg (1995)
# 135   137                             Man of the Year (1995)
# 136   138                             Neon Bible, The (1995)
# 137   139                                      Target (1995)
# 138   140                       Up Close and Personal (1996)
# 139   141                               Birdcage, The (1996)
# 140   142                            Shadows (Cienie) (1988)
# 141   143                                       Gospa (1995)
# 142   144                      Brothers McMullen, The (1995)
# 143   145                                    Bad Boys (1995)
# 144   146                Amazing Panda Adventure, The (1995)
# 145   147                     Basketball Diaries, The (1995)
# 146   148                   Awfully Big Adventure, An (1995)
# 147   149                                     Amateur (1994)
# 148   150                                   Apollo 13 (1995)
# 149   151                                     Rob Roy (1995)
# 150   152                              Addiction, The (1995)
# 151   153                              Batman Forever (1995)
# 152   154           Beauty of the Day (Belle de jour) (1967)
# 153   155                              Beyond Rangoon (1995)
# 154   156                            Blue in the Face (1995)
# 155   157                              Canadian Bacon (1995)
# 156   158                                      Casper (1995)
# 157   159                                    Clockers (1995)
# 158   160                                       Congo (1995)
# 159   161                                Crimson Tide (1995)
# 160   162                                       Crumb (1994)
# 161   163                                   Desperado (1995)
# 162   164                       Devil in a Blue Dress (1995)
# 163   165                  Die Hard: With a Vengeance (1995)
# 164   166                        Doom Generation, The (1995)
# 165   167                               Feast of July (1995)
# 166   168                                First Knight (1995)
# 167   169            Free Willy 2: The Adventure Home (1995)
# 168   170                                     Hackers (1995)
# 169   171                                     Jeffrey (1995)
# 170   172                             Johnny Mnemonic (1995)
# 171   173                                 Judge Dredd (1995)
# 172   174                                   Jury Duty (1995)
# 173   175                                        Kids (1995)
# 174   176                          Living in Oblivion (1995)
# 175   177                           Lord of Illusions (1995)
# 176   178                        Love & Human Remains (1993)
# 177   179                                    Mad Love (1995)
# 178   180                                    Mallrats (1995)
# 179   181     Mighty Morphin Power Rangers: The Movie (1995)
# 180   182                     Moonlight and Valentino (1995)
# 181   183                                Mute Witness (1994)
# 182   184                                       Nadja (1994)
# 183   185                                    Net, The (1995)
# 184   186                                 Nine Months (1995)
# 185   187                                  Party Girl (1995)
# 186   188                               Prophecy, The (1995)
# 187   189                                    Reckless (1995)
# 188   190                                        Safe (1995)
# 189   191                         Scarlet Letter, The (1995)
# 190   192                                   Show, The (1995)
# 191   193                                   Showgirls (1995)
# 192   194                                       Smoke (1995)
# 193   195                     Something to Talk About (1995)
# 194   196                                     Species (1995)
# 195   197                Stars Fell on Henrietta, The (1995)
# 196   198                                Strange Days (1995)
# 197   199  Umbrellas of Cherbourg, The (Parapluies de Che...
# 198   200                         Tie That Binds, The (1995)
# 199   201                                Three Wishes (1995)
# 200   202                               Total Eclipse (1995)
# 201   203  To Wong Foo, Thanks for Everything! Julie Newm...
# 202   204               Under Siege 2: Dark Territory (1995)
# 203   205                             Unstrung Heroes (1995)
# 204   206                                    Unzipped (1995)
# 205   207                       Walk in the Clouds, A (1995)
# 206   208                                  Waterworld (1995)
# 207   209                          White Man's Burden (1995)
# 208   210                                   Wild Bill (1995)
# 209   211                       Browning Version, The (1994)
# 210   212                                 Bushwhacked (1995)
# 211   213     Burnt by the Sun (Utomlyonnye solntsem) (1994)
# 212   214              Before the Rain (Pred dozhdot) (1994)
# 213   215                              Before Sunrise (1995)
# 214   216                               Billy Madison (1995)
# 215   217                             Babysitter, The (1995)
# 216   218                            Boys on the Side (1995)
# 217   219                                   Cure, The (1995)
# 218   220                                Castle Freak (1995)
# 219   222                           Circle of Friends (1995)
# 220   223                                      Clerks (1994)
# 221   224                            Don Juan DeMarco (1995)
# 222   225                                  Disclosure (1994)
# 223   226                                   Dream Man (1995)
# 224   227                                   Drop Zone (1994)
# 225   228                  Destiny Turns on the Radio (1995)
# 226   229                        Death and the Maiden (1994)
# 227   230                           Dolores Claiborne (1995)
# 228   231             Dumb & Dumber (Dumb and Dumber) (1994)
# 229   232        Eat Drink Man Woman (Yin shi nan nu) (1994)
# 230   233                                     Exotica (1994)
# 231   234                                Exit to Eden (1994)
# 232   235                                     Ed Wood (1994)
# 233   236                                 French Kiss (1995)
# 234   237                                Forget Paris (1995)
# 235   238  Far From Home: The Adventures of Yellow Dog (1...
# 236   239                              Goofy Movie, A (1995)
# 237   240                                    Hideaway (1995)
# 238   241                                       Fluke (1995)
# 239   242                      Farinelli: il castrato (1994)
# 240   243                                       Gordy (1995)
# 241   244                            Gumby: The Movie (1995)
# 242   245                           Glass Shield, The (1994)
# 243   246                                 Hoop Dreams (1994)
# 244   247                          Heavenly Creatures (1994)
# 245   248                                  Houseguest (1994)
# 246   249                            Immortal Beloved (1994)
# 247   250                Heavyweights (Heavy Weights) (1995)
# 248   251                                 Hunted, The (1995)
# 249   252                                        I.Q. (1994)
# 250   253  Interview with the Vampire: The Vampire Chroni...
# 251   254                          Jefferson in Paris (1995)
# 252   255                             Jerky Boys, The (1995)
# 253   256                                      Junior (1994)
# 254   257                                  Just Cause (1995)
# 255   258               Kid in King Arthur's Court, A (1995)
# 256   259                               Kiss of Death (1995)
# 257   260          Star Wars: Episode IV - A New Hope (1977)
# 258   261                                Little Women (1994)
# 259   262                          Little Princess, A (1995)
# 260   263                           Ladybird Ladybird (1994)
# 261   264                                   Enfer, L' (1994)
# 262   265  Like Water for Chocolate (Como agua para choco...
# 263   266                         Legends of the Fall (1994)
# 264   267                                 Major Payne (1995)
# 265   268                               Little Odessa (1994)
# 266   269                My Crazy Life (Mi vida loca) (1993)
# 267   270                                 Love Affair (1994)
# 268   271                               Losing Isaiah (1995)
# 269   272                 Madness of King George, The (1994)
# 270   273  Mary Shelley's Frankenstein (Frankenstein) (1994)
# 271   274                            Man of the House (1995)
# 272   275                                  Mixed Nuts (1994)
# 273   276                                  Milk Money (1994)
# 274   277                      Miracle on 34th Street (1994)
# 275   278                              Miami Rhapsody (1995)
# 276   279                                   My Family (1995)
# 277   280                         Murder in the First (1995)
# 278   281                               Nobody's Fool (1994)
# 279   282                                        Nell (1994)
# 280   283                            New Jersey Drive (1995)
# 281   284            New York Cop (Nyû Yôku no koppu) (1993)
# 282   285                               Beyond Bedlam (1993)
# 283   286                           Nemesis 2: Nebula (1995)
# 284   287                          Nina Takes a Lover (1994)
# 285   288                        Natural Born Killers (1994)
# 286   289                                    Only You (1994)
# 287   290                          Once Were Warriors (1994)
# 288   291                               Poison Ivy II (1996)
# 289   292                                    Outbreak (1995)
# 290   293  Léon: The Professional (a.k.a. The Professiona...
# 291   294                           Perez Family, The (1995)
# 292   295                  Pyromaniac's Love Story, A (1995)
# 293   296                                Pulp Fiction (1994)
# 294   297                                     Panther (1995)
# 295   298                    Pushing Hands (Tui shou) (1992)
# 296   299                                      Priest (1994)
# 297   300                                   Quiz Show (1994)
# 298   301                  Picture Bride (Bijo photo) (1994)
# 299   302             Queen Margot (Reine Margot, La) (1994)
# 300   303                     Quick and the Dead, The (1995)
# 301   304                                   Roommates (1995)
# 302   305               Ready to Wear (Pret-A-Porter) (1994)
# 303   306   Three Colors: Red (Trois couleurs: Rouge) (1994)
# 304   307   Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 305   308    Three Colors: White (Trzy kolory: Bialy) (1994)
# 306   309  Red Firecracker, Green Firecracker (Pao Da Shu...
# 307   310                                  Rent-a-Kid (1995)
# 308   311                               Relative Fear (1994)
# 309   312                     Stuart Saves His Family (1995)
# 310   313                          Swan Princess, The (1994)
# 311   314                   Secret of Roan Inish, The (1994)
# 312   315                             Specialist, The (1994)
# 313   316                                    Stargate (1994)
# 314   317                           Santa Clause, The (1994)
# 315   318                   Shawshank Redemption, The (1994)
# 316   319                               Shallow Grave (1994)
# 317   320                                      Suture (1993)
# 318   321  Strawberry and Chocolate (Fresa y chocolate) (...
# 319   322                        Swimming with Sharks (1995)
# 320   324                              Sum of Us, The (1994)
# 321   325              National Lampoon's Senior Trip (1995)
# 322   326                            To Live (Huozhe) (1994)
# 323   327                                   Tank Girl (1995)
# 324   328  Tales from the Crypt Presents: Demon Knight (1...
# 325   329                      Star Trek: Generations (1994)
# 326   330                         Tales from the Hood (1995)
# 327   331                                   Tom & Viv (1994)
# 328   332                       Village of the Damned (1995)
# 329   333                                   Tommy Boy (1995)
# 330   334                        Vanya on 42nd Street (1994)
# 331   335                                  Underneath (1995)
# 332   336                           Walking Dead, The (1995)
# 333   337                 What's Eating Gilbert Grape (1993)
# 334   338                                  Virtuosity (1995)
# 335   339                     While You Were Sleeping (1995)
# 336   340                                    War, The (1994)
# 337   341                            Double Happiness (1994)
# 338   342                            Muriel's Wedding (1994)
# 339   343                      Baby-Sitters Club, The (1995)
# 340   344                  Ace Ventura: Pet Detective (1994)
# 341   345  Adventures of Priscilla, Queen of the Desert, ...
# 342   346                                    Backbeat (1993)
# 343   347                                 Bitter Moon (1992)
# 344   348                       Bullets Over Broadway (1994)
# 345   349                    Clear and Present Danger (1994)
# 346   350                                 Client, The (1994)
# 347   351                            Corrina, Corrina (1994)
# 348   352                                    Crooklyn (1994)
# 349   353                                   Crow, The (1994)
# 350   354                                        Cobb (1994)
# 351   355                            Flintstones, The (1994)
# 352   356                                Forrest Gump (1994)
# 353   357                 Four Weddings and a Funeral (1994)
# 354   358                             Higher Learning (1995)
# 355   359                         I Like It Like That (1994)
# 356   360                              I Love Trouble (1994)
# 357   361                      It Could Happen to You (1994)
# 358   362                            Jungle Book, The (1994)
# 359   363  Wonderful, Horrible Life of Leni Riefenstahl, ...
# 360   364                              Lion King, The (1994)
# 361   365                               Little Buddha (1993)
# 362   366  Wes Craven's New Nightmare (Nightmare on Elm S...
# 363   367                                   Mask, The (1994)
# 364   368                                    Maverick (1994)
# 365   369          Mrs. Parker and the Vicious Circle (1994)
# 366   370          Naked Gun 33 1/3: The Final Insult (1994)
# 367   371                                  Paper, The (1994)
# 368   372                               Reality Bites (1994)
# 369   373                               Red Rock West (1992)
# 370   374                                 Richie Rich (1994)
# 371   375                                Safe Passage (1994)
# 372   376                             River Wild, The (1994)
# 373   377                                       Speed (1994)
# 374   378                                  Speechless (1994)
# 375   379                                     Timecop (1994)
# 376   380                                   True Lies (1994)
# 377   381                    When a Man Loves a Woman (1994)
# 378   382                                        Wolf (1994)
# 379   383                                  Wyatt Earp (1994)
# 380   384                                 Bad Company (1995)
# 381   385                     Man of No Importance, A (1994)
# 382   386                                      S.F.W. (1994)
# 383   387                     Low Down Dirty Shame, A (1994)
# 384   388                                   Boys Life (1995)
# 385   389                         Colonel Chabert, Le (1994)
# 386   390                Faster Pussycat! Kill! Kill! (1965)
# 387   391                               Jason's Lyric (1994)
# 388   392         Secret Adventures of Tom Thumb, The (1993)
# 389   393                              Street Fighter (1994)
# 390   394                                 Coldblooded (1995)
# 391   395                                Desert Winds (1995)
# 392   396                                   Fall Time (1995)
# 393   397                                   Fear, The (1995)
# 394   398                             Frank and Ollie (1995)
# 395   399                        Girl in the Cadillac (1995)
# 396   400                                      Homage (1995)
# 397   401                                      Mirage (1995)
# 398   402                                 Open Season (1996)
# 399   403                   Two Crimes (Dos crímenes) (1995)
# 400   404  Brother Minister: The Assassination of Malcolm...
# 401   405  Highlander III: The Sorcerer (a.k.a. Highlande...
# 402   406                                Federal Hill (1994)
# 403   407                     In the Mouth of Madness (1995)
# 404   408                                   8 Seconds (1994)
# 405   409                               Above the Rim (1994)
# 406   410                        Addams Family Values (1993)
# 407   411               Martin Lawrence: You So Crazy (1994)
# 408   412                       Age of Innocence, The (1993)
# 409   413                                    Airheads (1994)
# 410   414                           Air Up There, The (1994)
# 411   415                            Another Stakeout (1993)
# 412   416                                   Bad Girls (1994)
# 413   417                                   Barcelona (1994)
# 414   418                                 Being Human (1993)
# 415   419                    Beverly Hillbillies, The (1993)
# 416   420                       Beverly Hills Cop III (1994)
# 417   421                                Black Beauty (1994)
# 418   422                                       Blink (1994)
# 419   423                                  Blown Away (1994)
# 420   424                                  Blue Chips (1994)
# 421   425                                    Blue Sky (1994)
# 422   426                              Body Snatchers (1993)
# 423   427                               Boxing Helena (1993)
# 424   428                               Bronx Tale, A (1993)
# 425   429                                   Cabin Boy (1994)
# 426   430                               Calendar Girl (1993)
# 427   431                               Carlito's Way (1993)
# 428   432  City Slickers II: The Legend of Curly's Gold (...
# 429   433                                 Clean Slate (1994)
# 430   434                                 Cliffhanger (1993)
# 431   435                                   Coneheads (1993)
# 432   436                              Color of Night (1994)
# 433   437                         Cops and Robbersons (1994)
# 434   438                             Cowboy Way, The (1994)
# 435   439                              Dangerous Game (1993)
# 436   440                                        Dave (1993)
# 437   441                          Dazed and Confused (1993)
# 438   442                              Demolition Man (1993)
# 439   443                       Endless Summer 2, The (1994)
# 440   444                 Even Cowgirls Get the Blues (1993)
# 441   445                              Fatal Instinct (1993)
# 442   446      Farewell My Concubine (Ba wang bie ji) (1993)
# 443   447                                  Favor, The (1994)
# 444   448                                    Fearless (1993)
# 445   449                         Fear of a Black Hat (1994)
# 446   450                                 With Honors (1994)
# 447   451                              Flesh and Bone (1993)
# 448   452                                Widows' Peak (1994)
# 449   453                           For Love or Money (1993)
# 450   454                                   Firm, The (1993)
# 451   455                                  Free Willy (1993)
# 452   456                                       Fresh (1994)
# 453   457                               Fugitive, The (1993)
# 454   458                Geronimo: An American Legend (1993)
# 455   459                                Getaway, The (1994)
# 456   460                       Getting Even with Dad (1994)
# 457   461                                     Go Fish (1994)
# 458   462                       Good Man in Africa, A (1994)
# 459   463                               Guilty as Sin (1993)
# 460   464                                 Hard Target (1993)
# 461   465                              Heaven & Earth (1993)
# 462   466                        Hot Shots! Part Deux (1993)
# 463   467                             Live Nude Girls (1995)
# 464   468  Englishman Who Went Up a Hill But Came Down a ...
# 465   469                   House of the Spirits, The (1993)
# 466   470                               House Party 3 (1994)
# 467   471                        Hudsucker Proxy, The (1994)
# 468   472                            I'll Do Anything (1994)
# 469   473                             In the Army Now (1994)
# 470   474                         In the Line of Fire (1993)
# 471   475                   In the Name of the Father (1993)
# 472   476                                Inkwell, The (1994)
# 473   477              What's Love Got to Do with It? (1993)
# 474   478                             Jimmy Hollywood (1994)
# 475   479                              Judgment Night (1993)
# 476   480                               Jurassic Park (1993)
# 477   481                                  Kalifornia (1993)
# 478   482                                 Killing Zoe (1994)
# 479   483                            King of the Hill (1993)
# 480   484                                      Lassie (1994)
# 481   485                            Last Action Hero (1993)
# 482   486                             Life with Mikey (1993)
# 483   487                              Lightning Jack (1994)
# 484   488                                M. Butterfly (1993)
# 485   489                             Made in America (1993)
# 486   490                                      Malice (1993)
# 487   491                     Man Without a Face, The (1993)
# 488   492                    Manhattan Murder Mystery (1993)
# 489   493                           Menace II Society (1993)
# 490   494                          Executive Decision (1996)
# 491   495  In the Realm of the Senses (Ai no corrida) (1976)
# 492   496                        What Happened Was... (1994)
# 493   497                      Much Ado About Nothing (1993)
# 494   498                                   Mr. Jones (1993)
# 495   499                               Mr. Wonderful (1993)
# 496   500                              Mrs. Doubtfire (1993)
# 497   501                                       Naked (1993)
# 498   502                        Next Karate Kid, The (1994)
# 499   503                                New Age, The (1994)
# 500   504                                   No Escape (1994)
# 501   505                                       North (1994)
# 502   506                                     Orlando (1992)
# 503   507                            Perfect World, A (1993)
# 504   508                                Philadelphia (1993)
# 505   509                                  Piano, The (1993)
# 506   510                              Poetic Justice (1993)
# 507   511                                Program, The (1993)
# 508   512                         Puppet Masters, The (1994)
# 509   513                           Radioland Murders (1994)
# 510   514                                    Ref, The (1994)
# 511   515                     Remains of the Day, The (1993)
# 512   516                             Renaissance Man (1994)
# 513   517                                  Rising Sun (1993)
# 514   518                      Road to Wellville, The (1994)
# 515   519                                   RoboCop 3 (1993)
# 516   520                   Robin Hood: Men in Tights (1993)
# 517   521                           Romeo Is Bleeding (1993)
# 518   522                              Romper Stomper (1992)
# 519   523                            Ruby in Paradise (1993)
# 520   524                                        Rudy (1993)
# 521   525               Saint of Fort Washington, The (1993)
# 522   526           Savage Nights (Nuits fauves, Les) (1992)
# 523   527                            Schindler's List (1993)
# 524   528                                  Scout, The (1994)
# 525   529                 Searching for Bobby Fischer (1993)
# 526   530                                 Second Best (1994)
# 527   531                          Secret Garden, The (1993)
# 528   532                                  Serial Mom (1994)
# 529   533                                 Shadow, The (1994)
# 530   534                                 Shadowlands (1993)
# 531   535                                  Short Cuts (1993)
# 532   536                     Simple Twist of Fate, A (1994)
# 533   537                                      Sirens (1994)
# 534   538                   Six Degrees of Separation (1993)
# 535   539                        Sleepless in Seattle (1993)
# 536   540                                      Sliver (1993)
# 537   541                                Blade Runner (1982)
# 538   542                                  Son in Law (1993)
# 539   543                So I Married an Axe Murderer (1993)
# 540   544                           Striking Distance (1993)
# 541   545                                       Harem (1985)
# 542   546                           Super Mario Bros. (1993)
# 543   547                          Surviving the Game (1994)
# 544   548                           Terminal Velocity (1994)
# 545   549    Thirty-Two Short Films About Glenn Gould (1993)
# 546   550                                   Threesome (1994)
# 547   551             Nightmare Before Christmas, The (1993)
# 548   552                       Three Musketeers, The (1993)
# 549   553                                   Tombstone (1993)
# 550   554                               Trial by Jury (1994)
# 551   555                                True Romance (1993)
# 552   556                               War Room, The (1993)
# 553   558                             Pagemaster, The (1994)
# 554   559                               Paris, France (1993)
# 555   560                  Beans of Egypt, Maine, The (1994)
# 556   561                  Killer (Bulletproof Heart) (1994)
# 557   562                    Welcome to the Dollhouse (1995)
# 558   563                                    Germinal (1993)
# 559   564                                     Chasers (1994)
# 560   565                                      Cronos (1993)
# 561   566                           Naked in New York (1994)
# 562   567                                        Kika (1993)
# 563   568                          Bhaji on the Beach (1993)
# 564   569                           Little Big League (1994)
# 565   570                Slingshot, The (Kådisbellan) (1993)
# 566   571                           Wedding Gift, The (1994)
# 567   572                             Foreign Student (1994)
# 568   573  Ciao, Professore! (Io speriamo che me la cavo)...
# 569   574                         Spanking the Monkey (1994)
# 570   575                         Little Rascals, The (1994)
# 571   576                                      Fausto (1993)
# 572   577                                       Andre (1994)
# 573   579                    Escort, The (Scorta, La) (1993)
# 574   580                            Princess Caraboo (1994)
# 575   581                       Celluloid Closet, The (1995)
# 576   582                      Métisse (Café au Lait) (1993)
# 577   583                    Dear Diary (Caro Diario) (1994)
# 578   584  I Don't Want to Talk About It (De eso no se ha...
# 579   585                      Brady Bunch Movie, The (1995)
# 580   586                                  Home Alone (1990)
# 581   587                                       Ghost (1990)
# 582   588                                     Aladdin (1992)
# 583   589                  Terminator 2: Judgment Day (1991)
# 584   590                          Dances with Wolves (1990)
# 585   591                            Tough and Deadly (1995)
# 586   592                                      Batman (1989)
# 587   593                   Silence of the Lambs, The (1991)
# 588   594             Snow White and the Seven Dwarfs (1937)
# 589   595                        Beauty and the Beast (1991)
# 590   596                                   Pinocchio (1940)
# 591   597                                Pretty Woman (1990)
# 592   598             Window to Paris (Okno v Parizh) (1994)
# 593   599                             Wild Bunch, The (1969)
# 594   600                              Love and a .45 (1994)
# 595   601          Wooden Man's Bride, The (Yan shen) (1994)
# 596   602                      Great Day in Harlem, A (1994)
# 597   603                               Bye Bye, Love (1995)
# 598   604                                   Criminals (1996)
# 599   605                                One Fine Day (1996)
# 600   606             Candyman: Farewell to the Flesh (1995)
# 601   607                                     Century (1993)
# 602   608                                       Fargo (1996)
# 603   609    Homeward Bound II: Lost in San Francisco (1996)
# 604   610                                 Heavy Metal (1981)
# 605   611                       Hellraiser: Bloodline (1996)
# 606   612                             Pallbearer, The (1996)
# 607   613                                   Jane Eyre (1996)
# 608   614                                      Loaded (1994)
# 609   615     Bread and Chocolate (Pane e cioccolata) (1973)
# 610   616                             Aristocats, The (1970)
# 611   617  Flower of My Secret, The (La flor de mi secret...
# 612   618                                    Two Much (1995)
# 613   619                                          Ed (1996)
# 614   620  Scream of Stone (Cerro Torre: Schrei aus Stein...
# 615   621                          My Favorite Season (1993)
# 616   623                            Modern Affair, A (1995)
# 617   624              Condition Red (Beyond the Law) (1995)
# 618   625                                 Asfour Stah (1990)
# 619   626          Thin Line Between Love and Hate, A (1996)
# 620   627                            Last Supper, The (1995)
# 621   628                                 Primal Fear (1996)
# 622   629                                        Rude (1995)
# 623   630                                Carried Away (1996)
# 624   631                     All Dogs Go to Heaven 2 (1996)
# 625   632        Land and Freedom (Tierra y libertad) (1995)
# 626   633                             Denise Calls Up (1995)
# 627   634                                Theodore Rex (1995)
# 628   635                             Family Thing, A (1996)
# 629   636                                       Frisk (1995)
# 630   637                                  Sgt. Bilko (1996)
# 631   638                              Jack and Sarah (1995)
# 632   639                                      Girl 6 (1996)
# 633   640                                  Diabolique (1996)
# 634   641  Little Indian, Big City (Un indien dans la vil...
# 635   642                                       Roula (1995)
# 636   643              Peanuts - Die Bank zahlt alles (1996)
# 637   644                               Happy Weekend (1996)
# 638   645                     Nelly & Monsieur Arnaud (1995)
# 639   647                          Courage Under Fire (1996)
# 640   648                         Mission: Impossible (1996)
# 641   649                 Cold Fever (Á köldum klaka) (1995)
# 642   650                               Moll Flanders (1996)
# 643   651                              Superweib, Das (1996)
# 644   652                          301, 302 (301/302) (1995)
# 645   653                                 Dragonheart (1996)
# 646   654  And Nobody Weeps for Me (Und keiner weint mir ...
# 647   655       My Mother's Courage (Mutters Courage) (1995)
# 648   656                                       Eddie (1996)
# 649   657                                 Yankee Zulu (1994)
# 650   658                             Billy's Holiday (1995)
# 651   659                  Purple Noon (Plein soleil) (1960)
# 652   660                                      August (1996)
# 653   661                   James and the Giant Peach (1996)
# 654   662                                        Fear (1996)
# 655   663               Kids in the Hall: Brain Candy (1996)
# 656   664                                    Faithful (1996)
# 657   665                                 Underground (1995)
# 658   666     All Things Fair (Lust och fägring stor) (1995)
# 659   667  Bloodsport 2 (a.k.a. Bloodsport II: The Next K...
# 660   668   Song of the Little Road (Pather Panchali) (1955)
# 661   670             World of Apu, The (Apur Sansar) (1959)
# 662   671     Mystery Science Theater 3000: The Movie (1996)
# 663   672                                  Tarantella (1995)
# 664   673                                   Space Jam (1996)
# 665   674                                  Barbarella (1968)
# 666   675                          Hostile Intentions (1994)
# 667   676                                   They Bite (1996)
# 668   678            Some Folks Call It a Sling Blade (1993)
# 669   679                     Run of the Country, The (1995)
# 670   680  Alphaville (Alphaville, une étrange aventure d...
# 671   681               Coup de torchon (Clean Slate) (1981)
# 672   682         Tigrero: A Film That Was Never Made (1994)
# 673   683       Eye of Vichy, The (Oeil de Vichy, L') (1993)
# 674   684                                     Windows (1980)
# 675   685                               It's My Party (1996)
# 676   687                                Country Life (1994)
# 677   688                        Operation Dumbo Drop (1995)
# 678   690             Promise, The (Versprechen, Das) (1995)
# 679   691                           Mrs. Winterbourne (1996)
# 680   692                                        Solo (1996)
# 681   693    Under the Domim Tree (Etz Hadomim Tafus) (1994)
# 682   694                             Substitute, The (1996)
# 683   695                                  True Crime (1996)
# 684   696                              Butterfly Kiss (1995)
# 685   697                           Feeling Minnesota (1996)
# 686   698                              Delta of Venus (1995)
# 687   699                        To Cross the Rubicon (1991)
# 688   700                                       Angus (1995)
# 689   701                                       Daens (1992)
# 690   702                                       Faces (1968)
# 691   703                                        Boys (1996)
# 692   704                                  Quest, The (1996)
# 693   705                                        Cosi (1996)
# 694   706                                 Sunset Park (1996)
# 695   707                            Mulholland Falls (1996)
# 696   708                Truth About Cats & Dogs, The (1996)
# 697   709                            Oliver & Company (1988)
# 698   710                                Celtic Pride (1996)
# 699   711                                     Flipper (1996)
# 700   712                                    Captives (1994)
# 701   713                         Of Love and Shadows (1994)
# 702   714                                    Dead Man (1995)
# 703   715  Horseman on the Roof, The (Hussard sur le toit...
# 704   716                         Switchblade Sisters (1975)
# 705   717                Mouth to Mouth (Boca a boca) (1995)
# 706   718              Visitors, The (Visiteurs, Les) (1993)
# 707   719                                Multiplicity (1996)
# 708   720  Wallace & Gromit: The Best of Aardman Animatio...
# 709   721           Halfmoon (Paul Bowles - Halbmond) (1995)
# 710   722    Haunted World of Edward D. Wood Jr., The (1996)
# 711   723                                 Two Friends (1986)
# 712   724                                  Craft, The (1996)
# 713   725                       Great White Hype, The (1996)
# 714   726                                  Last Dance (1996)
# 715   727                                 War Stories (1995)
# 716   728                           Cold Comfort Farm (1995)
# 717   729  Institute Benjamenta, or This Dream People Cal...
# 718   730                                    Low Life (1994)
# 719   731                          Heaven's Prisoners (1996)
# 720   732                           Original Gangstas (1996)
# 721   733                                   Rock, The (1996)
# 722   734                    Getting Away With Murder (1996)
# 723   735         Cemetery Man (Dellamorte Dellamore) (1994)
# 724   736                                     Twister (1996)
# 725   737                                   Barb Wire (1996)
# 726   738                                   Garçu, Le (1995)
# 727   739                      Honey Moon (Honigmond) (1996)
# 728   741         Ghost in the Shell (Kôkaku kidôtai) (1995)
# 729   742                                     Thinner (1996)
# 730   743                                    Spy Hard (1996)
# 731   744                         Brothers in Trouble (1995)
# 732   745             Wallace & Gromit: A Close Shave (1995)
# 733   746                               Force of Evil (1948)
# 734   747                                Stupids, The (1996)
# 735   748                                Arrival, The (1996)
# 736   749                    Man from Down Under, The (1943)
# 737   750  Dr. Strangelove or: How I Learned to Stop Worr...
# 738   751                                     Careful (1992)
# 739   752                       Vermont Is For Lovers (1992)
# 740   753                        Month by the Lake, A (1995)
# 741   754   Gold Diggers: The Secret of Bear Mountain (1995)
# 742   755                                         Kim (1950)
# 743   756      Carmen Miranda: Bananas Is My Business (1994)
# 744   757            Ashes of Time (Dung che sai duk) (1994)
# 745   758                          Jar, The (Khomreh) (1992)
# 746   759             Maya Lin: A Strong Clear Vision (1994)
# 747   760                                  Stalingrad (1993)
# 748   761                                Phantom, The (1996)
# 749   762                                  Striptease (1996)
# 750   763  Last of the High Kings, The (a.k.a. Summer Fli...
# 751   764                                       Heavy (1995)
# 752   765                                        Jack (1996)
# 753   766                          I Shot Andy Warhol (1996)
# 754   767                             Grass Harp, The (1995)
# 755   768                      Someone Else's America (1995)
# 756   769          Marlene Dietrich: Shadow and Light (1996)
# 757   770                                 Costa Brava (1946)
# 758   771  Life Is Rosy (a.k.a. Life Is Beautiful) (Vie e...
# 759   772                             Quartier Mozart (1992)
# 760   773                                 Touki Bouki (1973)
# 761   774              Wend Kuuni (a.k.a. God's Gift) (1982)
# 762   775                         Spirits of the Dead (1968)
# 763   776                                   Babyfever (1994)
# 764   777                              Pharaoh's Army (1995)
# 765   778                               Trainspotting (1996)
# 766   779                          'Til There Was You (1997)
# 767   780               Independence Day (a.k.a. ID4) (1996)
# 768   781                             Stealing Beauty (1996)
# 769   782                                    Fan, The (1996)
# 770   783                Hunchback of Notre Dame, The (1996)
# 771   784                              Cable Guy, The (1996)
# 772   785                                     Kingpin (1996)
# 773   786                                      Eraser (1996)
# 774   787                 Gate of Heavenly Peace, The (1995)
# 775   788                        Nutty Professor, The (1996)
# 776   789  I, the Worst of All (Yo, la peor de todas) (1990)
# 777   790  Unforgettable Summer, An (Un été inoubliable) ...
# 778   791  Last Klezmer: Leopold Kozlowski, His Life and ...
# 779   792  Hungarian Fairy Tale, A (Hol volt, hol nem vol...
# 780   793  My Life and Times With Antonin Artaud (En comp...
# 781   794                    Midnight Dancers (Sibak) (1994)
# 782   795                            Somebody to Love (1994)
# 783   796                       Very Natural Thing, A (1974)
# 784   797  Old Lady Who Walked in the Sea, The (Vieille q...
# 785   798                                    Daylight (1996)
# 786   799                            Frighteners, The (1996)
# 787   800                                   Lone Star (1996)
# 788   801                             Harriet the Spy (1996)
# 789   802                                  Phenomenon (1996)
# 790   803                         Walking and Talking (1996)
# 791   804                               She's the One (1996)
# 792   805                             Time to Kill, A (1996)
# 793   806                            American Buffalo (1996)
# 794   807  Rendezvous in Paris (Rendez-vous de Paris, Les...
# 795   808                                      Alaska (1996)
# 796   809                                        Fled (1996)
# 797   810                                      Kazaam (1996)
# 798   812                 Magic Hunter (Büvös vadász) (1994)
# 799   813                            Larger Than Life (1996)
# 800   814                          Boy Called Hate, A (1995)
# 801   815                                    Power 98 (1996)
# 802   816                                  Two Deaths (1995)
# 803   818                        Very Brady Sequel, A (1996)
# 804   819                        Stefano Quantestorie (1993)
# 805   820  Death in the Garden (Mort en ce jardin, La) (1...
# 806   821                            Crude Oasis, The (1995)
# 807   822                                    Hedd Wyn (1992)
# 808   823         Collector, The (La collectionneuse) (1967)
# 809   824                               Kaspar Hauser (1993)
# 810   825                  Regular Guys (Echte Kerle) (1996)
# 811   826                   Women Robbers (Diebinnen) (1995)
# 812   827                   Convent, The (O Convento) (1995)
# 813   828                Adventures of Pinocchio, The (1996)
# 814   829                             Joe's Apartment (1996)
# 815   830                       First Wives Club, The (1996)
# 816   831                                   Stonewall (1995)
# 817   832                                      Ransom (1996)
# 818   833                            High School High (1996)
# 819   834                                  Phat Beach (1996)
# 820   835                                     Foxfire (1996)
# 821   836                              Chain Reaction (1996)
# 822   837                                     Matilda (1996)
# 823   838                                        Emma (1996)
# 824   839                   Crow: City of Angels, The (1996)
# 825   840                                House Arrest (1996)
# 826   841  Eyes Without a Face (Yeux sans visage, Les) (1...
# 827   842  Tales from the Crypt Presents: Bordello of Blo...
# 828   843                                  Lotto Land (1995)
# 829   844  Story of Xinghua, The (Xinghua san yue tian) (...
# 830   845  Day the Sun Turned Cold, The (Tianguo niezi) (...
# 831   846                                       Flirt (1995)
# 832   847                            Big Squeeze, The (1996)
# 833   848                         Spitfire Grill, The (1996)
# 834   849                            Escape from L.A. (1996)
# 835   850                             Cyclo (Xich lo) (1995)
# 836   851                                    Basquiat (1996)
# 837   852                                     Tin Cup (1996)
# 838   853                                       Dingo (1991)
# 839   854  Ballad of Narayama, The (Narayama Bushiko) (1958)
# 840   855  Every Other Weekend (Un week-end sur deux) (1990)
# 841   856                             Mille bolle blu (1993)
# 842   857          Crows and Sparrows (Wuya yu maque) (1949)
# 843   858                              Godfather, The (1972)
# 844   859                      Hippie Revolution, The (1996)
# 845   860        Maybe, Maybe Not (Bewegte Mann, Der) (1994)
# 846   861  Supercop (Police Story 3: Supercop) (Jing cha ...
# 847   862                                  Manny & Lo (1996)
# 848   864                                   Wife, The (1995)
# 849   865                                 Small Faces (1996)
# 850   866                                       Bound (1996)
# 851   867                                     Carpool (1996)
# 852   868                          Death in Brunswick (1991)
# 853   869                                 Kansas City (1996)
# 854   870                                Gone Fishin' (1997)
# 855   871                                Lover's Knot (1996)
# 856   872              Vive L'Amour (Ai qing wan sui) (1994)
# 857   873       Shadow of Angels (Schatten der Engel) (1976)
# 858   874                 Killer: A Journal of Murder (1995)
# 859   875                             Nothing to Lose (1994)
# 860   876     Supercop 2 (Project S) (Chao ji ji hua) (1993)
# 861   877                                  Girls Town (1996)
# 862   878                                     Bye-Bye (1995)
# 863   879                                  Relic, The (1997)
# 864   880                   Island of Dr. Moreau, The (1996)
# 865   881                                   First Kid (1996)
# 866   882                         Trigger Effect, The (1996)
# 867   884                               Sweet Nothing (1996)
# 868   885                                       Bogus (1996)
# 869   886                                 Bulletproof (1996)
# 870   887                              Talk of Angels (1998)
# 871   888  Land Before Time III: The Time of the Great Gi...
# 872   889                                  1-900 (06) (1994)
# 873   890                   Baton Rouge (Bâton rouge) (1988)
# 874   891  Halloween: The Curse of Michael Myers (Hallowe...
# 875   892                               Twelfth Night (1996)
# 876   893                                Mother Night (1996)
# 877   894                                    Liebelei (1933)
# 878   895                               Venice/Venice (1992)
# 879   896           Wild Reeds (Les roseaux sauvages) (1994)
# 880   897                     For Whom the Bell Tolls (1943)
# 881   898                     Philadelphia Story, The (1940)
# 882   899                         Singin' in the Rain (1952)
# 883   900                       American in Paris, An (1951)
# 884   901                                  Funny Face (1957)
# 885   902                      Breakfast at Tiffany's (1961)
# 886   903                                     Vertigo (1958)
# 887   904                                 Rear Window (1954)
# 888   905                       It Happened One Night (1934)
# 889   906                                    Gaslight (1944)
# 890   907                           Gay Divorcee, The (1934)
# 891   908                          North by Northwest (1959)
# 892   909                              Apartment, The (1960)
# 893   910                            Some Like It Hot (1959)
# 894   911                                     Charade (1963)
# 895   912                                  Casablanca (1942)
# 896   913                         Maltese Falcon, The (1941)
# 897   914                                My Fair Lady (1964)
# 898   915                                     Sabrina (1954)
# 899   916                               Roman Holiday (1953)
# 900   917                        Little Princess, The (1939)
# 901   918                        Meet Me in St. Louis (1944)
# 902   919                           Wizard of Oz, The (1939)
# 903   920                          Gone with the Wind (1939)
# 904   921                            My Favorite Year (1982)
# 905   922      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 906   923                                Citizen Kane (1941)
# 907   924                       2001: A Space Odyssey (1968)
# 908   925                             Golden Earrings (1947)
# 909   926                               All About Eve (1950)
# 910   927                                  Women, The (1939)
# 911   928                                     Rebecca (1940)
# 912   929                       Foreign Correspondent (1940)
# 913   930                                   Notorious (1946)
# 914   931                                  Spellbound (1945)
# 915   932                      Affair to Remember, An (1957)
# 916   933                            To Catch a Thief (1955)
# 917   934                         Father of the Bride (1950)
# 918   935                             Band Wagon, The (1953)
# 919   936                                   Ninotchka (1939)
# 920   937                       Love in the Afternoon (1957)
# 921   938                                        Gigi (1958)
# 922   939                    Reluctant Debutante, The (1958)
# 923   940               Adventures of Robin Hood, The (1938)
# 924   941                          Mark of Zorro, The (1940)
# 925   942                                       Laura (1944)
# 926   943                    Ghost and Mrs. Muir, The (1947)
# 927   944                                Lost Horizon (1937)
# 928   945                                     Top Hat (1935)
# 929   946                          To Be or Not to Be (1942)
# 930   947                              My Man Godfrey (1936)
# 931   948                                       Giant (1956)
# 932   949                                East of Eden (1955)
# 933   950                               Thin Man, The (1934)
# 934   951                             His Girl Friday (1940)
# 935   952                 Around the World in 80 Days (1956)
# 936   953                       It's a Wonderful Life (1946)
# 937   954                Mr. Smith Goes to Washington (1939)
# 938   955                            Bringing Up Baby (1938)
# 939   956                              Penny Serenade (1941)
# 940   957                         Scarlet Letter, The (1926)
# 941   958                           Lady of Burlesque (1943)
# 942   959                            Of Human Bondage (1934)
# 943   960                        Angel on My Shoulder (1946)
# 944   961                      Little Lord Fauntleroy (1936)
# 945   962  They Made Me a Criminal (I Became a Criminal) ...
# 946   963                      Inspector General, The (1949)
# 947   964                        Angel and the Badman (1947)
# 948   965                               39 Steps, The (1935)
# 949   966                          Walk in the Sun, A (1945)
# 950   967                                 Outlaw, The (1943)
# 951   968                    Night of the Living Dead (1968)
# 952   969                          African Queen, The (1951)
# 953   970                              Beat the Devil (1953)
# 954   971                       Cat on a Hot Tin Roof (1958)
# 955   972                  Last Time I Saw Paris, The (1954)
# 956   973                               Meet John Doe (1941)
# 957   974                                     Algiers (1938)
# 958   975                     Something to Sing About (1937)
# 959   976                         Farewell to Arms, A (1932)
# 960   977                            Moonlight Murder (1936)
# 961   979                            Nothing Personal (1995)
# 962   980  Yes, Madam (a.k.a. Police Assassins) (a.k.a. I...
# 963   981                            Dangerous Ground (1997)
# 964   982                                      Picnic (1955)
# 965   983                             Madagascar Skin (1995)
# 966   984                       Pompatus of Love, The (1996)
# 967   985                               Small Wonders (1995)
# 968   986                               Fly Away Home (1996)
# 969   987                                       Bliss (1997)
# 970   988                           Grace of My Heart (1996)
# 971   989          Brother of Sleep (Schlafes Bruder) (1995)
# 972   990                                Maximum Risk (1996)
# 973   991                             Michael Collins (1996)
# 974   992                        Rich Man's Wife, The (1996)
# 975   993                                    Infinity (1996)
# 976   994                                   Big Night (1996)
# 977   996                           Last Man Standing (1996)
# 978   997                                      Caught (1996)
# 979   998                                  Set It Off (1996)
# 980   999                        2 Days in the Valley (1996)
# 981  1000                                     Curdled (1996)
# 982  1001                Associate, The (Associé, L') (1979)
# 983  1002                              Ed's Next Move (1996)
# 984  1003                            Extreme Measures (1996)
# 985  1004                            Glimmer Man, The (1996)
# 986  1005                        D3: The Mighty Ducks (1996)
# 987  1006                                Chamber, The (1996)
# 988  1007                    Apple Dumpling Gang, The (1975)
# 989  1008    Davy Crockett, King of the Wild Frontier (1955)
# 990  1009                    Escape to Witch Mountain (1975)
# 991  1010                               Love Bug, The (1969)
# 992  1011                          Herbie Rides Again (1974)
# 993  1012                                  Old Yeller (1957)
# 994  1013                            Parent Trap, The (1961)
# 995  1014                                   Pollyanna (1960)
# 996  1015      Homeward Bound: The Incredible Journey (1993)
# 997  1016                             Shaggy Dog, The (1959)
# 998  1017                       Swiss Family Robinson (1960)
# 999  1018                              That Darn Cat! (1965)

# %%
ratings_df.limit(1000).toPandas() # convert into a Pandas DataFrame and display
# Out:
#      userId  movieId  rating
# 0         1        2     3.5
# 1         1       29     3.5
# 2         1       32     3.5
# 3         1       47     3.5
# 4         1       50     3.5
# 5         1      112     3.5
# 6         1      151     4.0
# 7         1      223     4.0
# 8         1      253     4.0
# 9         1      260     4.0
# 10        1      293     4.0
# 11        1      296     4.0
# 12        1      318     4.0
# 13        1      337     3.5
# 14        1      367     3.5
# 15        1      541     4.0
# 16        1      589     3.5
# 17        1      593     3.5
# 18        1      653     3.0
# 19        1      919     3.5
# 20        1      924     3.5
# 21        1     1009     3.5
# 22        1     1036     4.0
# 23        1     1079     4.0
# 24        1     1080     3.5
# 25        1     1089     3.5
# 26        1     1090     4.0
# 27        1     1097     4.0
# 28        1     1136     3.5
# 29        1     1193     3.5
# 30        1     1196     4.5
# 31        1     1198     4.5
# 32        1     1200     4.0
# 33        1     1201     3.0
# 34        1     1208     3.5
# 35        1     1214     4.0
# 36        1     1215     4.0
# 37        1     1217     3.5
# 38        1     1219     4.0
# 39        1     1222     3.5
# 40        1     1240     4.0
# 41        1     1243     3.0
# 42        1     1246     3.5
# 43        1     1249     4.0
# 44        1     1258     4.0
# 45        1     1259     4.0
# 46        1     1261     3.5
# 47        1     1262     3.5
# 48        1     1266     4.0
# 49        1     1278     4.0
# 50        1     1291     3.5
# 51        1     1304     3.0
# 52        1     1321     4.0
# 53        1     1333     4.0
# 54        1     1348     3.5
# 55        1     1350     3.5
# 56        1     1358     4.0
# 57        1     1370     3.0
# 58        1     1374     4.0
# 59        1     1387     4.0
# 60        1     1525     3.0
# 61        1     1584     3.5
# 62        1     1750     3.5
# 63        1     1848     3.5
# 64        1     1920     3.5
# 65        1     1967     4.0
# 66        1     1994     3.5
# 67        1     1997     3.5
# 68        1     2021     4.0
# 69        1     2100     4.0
# 70        1     2118     4.0
# 71        1     2138     4.0
# 72        1     2140     4.0
# 73        1     2143     4.0
# 74        1     2173     4.0
# 75        1     2174     4.0
# 76        1     2193     4.0
# 77        1     2194     3.5
# 78        1     2253     3.5
# 79        1     2288     4.0
# 80        1     2291     4.0
# 81        1     2542     4.0
# 82        1     2628     4.0
# 83        1     2644     3.5
# 84        1     2648     3.5
# 85        1     2664     3.5
# 86        1     2683     3.5
# 87        1     2692     3.5
# 88        1     2716     3.5
# 89        1     2761     3.0
# 90        1     2762     4.0
# 91        1     2804     3.5
# 92        1     2872     4.0
# 93        1     2918     3.5
# 94        1     2944     4.0
# 95        1     2947     3.5
# 96        1     2959     4.0
# 97        1     2968     4.0
# 98        1     3000     3.5
# 99        1     3030     3.0
# 100       1     3037     3.5
# 101       1     3081     4.0
# 102       1     3153     4.0
# 103       1     3265     3.5
# 104       1     3438     3.5
# 105       1     3476     3.5
# 106       1     3479     4.0
# 107       1     3489     4.0
# 108       1     3499     4.0
# 109       1     3889     4.0
# 110       1     3932     3.0
# 111       1     3996     4.0
# 112       1     3997     3.5
# 113       1     4011     4.0
# 114       1     4027     4.0
# 115       1     4105     3.5
# 116       1     4128     4.0
# 117       1     4133     3.0
# 118       1     4226     3.5
# 119       1     4306     4.0
# 120       1     4446     3.5
# 121       1     4467     4.0
# 122       1     4571     4.0
# 123       1     4720     3.5
# 124       1     4754     4.0
# 125       1     4878     3.5
# 126       1     4896     4.0
# 127       1     4911     4.0
# 128       1     4915     3.0
# 129       1     4941     3.5
# 130       1     4980     3.5
# 131       1     4993     5.0
# 132       1     5026     4.0
# 133       1     5039     4.0
# 134       1     5040     3.0
# 135       1     5146     3.5
# 136       1     5171     4.0
# 137       1     5540     4.0
# 138       1     5679     3.5
# 139       1     5797     4.0
# 140       1     5816     4.0
# 141       1     5898     3.5
# 142       1     5952     5.0
# 143       1     5999     3.5
# 144       1     6093     4.0
# 145       1     6242     3.5
# 146       1     6333     4.0
# 147       1     6502     3.5
# 148       1     6539     4.0
# 149       1     6754     4.0
# 150       1     6755     3.5
# 151       1     6774     4.0
# 152       1     6807     3.5
# 153       1     6834     3.5
# 154       1     6888     3.0
# 155       1     7001     3.5
# 156       1     7045     3.5
# 157       1     7046     4.0
# 158       1     7153     5.0
# 159       1     7164     3.5
# 160       1     7247     3.5
# 161       1     7387     3.5
# 162       1     7389     4.0
# 163       1     7438     4.0
# 164       1     7449     3.5
# 165       1     7454     4.0
# 166       1     7482     3.0
# 167       1     7757     4.0
# 168       1     8368     4.0
# 169       1     8482     3.5
# 170       1     8507     5.0
# 171       1     8636     4.5
# 172       1     8690     3.5
# 173       1     8961     4.0
# 174       1    31696     4.0
# 175       2        3     4.0
# 176       2       62     5.0
# 177       2       70     5.0
# 178       2      110     4.0
# 179       2      242     3.0
# 180       2      260     5.0
# 181       2      266     5.0
# 182       2      469     3.0
# 183       2      480     5.0
# 184       2      541     5.0
# 185       2      589     5.0
# 186       2      891     2.0
# 187       2      908     4.0
# 188       2      924     5.0
# 189       2     1121     3.0
# 190       2     1196     5.0
# 191       2     1210     5.0
# 192       2     1214     5.0
# 193       2     1249     5.0
# 194       2     1259     5.0
# 195       2     1270     5.0
# 196       2     1327     5.0
# 197       2     1356     5.0
# 198       2     1544     5.0
# 199       2     1580     4.0
# 200       2     1673     4.0
# 201       2     1748     5.0
# 202       2     1965     3.0
# 203       2     1969     2.0
# 204       2     1970     2.0
# 205       2     1971     2.0
# 206       2     1972     2.0
# 207       2     1973     3.0
# 208       2     1974     5.0
# 209       2     1986     2.0
# 210       2     2291     2.0
# 211       2     2454     4.0
# 212       2     2455     4.0
# 213       2     2791     2.0
# 214       2     2858     3.0
# 215       2     2948     5.0
# 216       2     2951     4.0
# 217       2     3150     4.0
# 218       2     3159     3.0
# 219       2     3173     4.0
# 220       2     3450     5.0
# 221       2     3513     5.0
# 222       2     3534     3.0
# 223       2     3555     4.0
# 224       2     3565     3.0
# 225       2     3703     4.0
# 226       2     3753     4.0
# 227       2     3917     4.0
# 228       2     3918     3.0
# 229       2     3923     4.0
# 230       2     3926     4.0
# 231       2     3927     5.0
# 232       2     3928     5.0
# 233       2     3930     5.0
# 234       2     3937     4.0
# 235       2     3959     5.0
# 236       3        1     4.0
# 237       3       24     3.0
# 238       3       32     4.0
# 239       3       50     5.0
# 240       3      160     3.0
# 241       3      173     2.0
# 242       3      175     5.0
# 243       3      196     3.0
# 244       3      223     5.0
# 245       3      260     5.0
# 246       3      316     5.0
# 247       3      318     5.0
# 248       3      329     5.0
# 249       3      337     3.0
# 250       3      440     3.0
# 251       3      442     3.0
# 252       3      457     5.0
# 253       3      480     5.0
# 254       3      490     5.0
# 255       3      512     2.0
# 256       3      541     5.0
# 257       3      589     4.0
# 258       3      593     5.0
# 259       3      610     4.0
# 260       3      718     3.0
# 261       3      780     3.0
# 262       3      788     4.0
# 263       3      858     5.0
# 264       3      904     5.0
# 265       3      905     3.0
# 266       3      919     4.0
# 267       3      924     5.0
# 268       3      953     5.0
# 269       3      968     3.0
# 270       3     1037     3.0
# 271       3     1060     5.0
# 272       3     1073     5.0
# 273       3     1077     4.0
# 274       3     1079     4.0
# 275       3     1084     5.0
# 276       3     1089     5.0
# 277       3     1094     4.0
# 278       3     1097     5.0
# 279       3     1103     4.0
# 280       3     1125     4.0
# 281       3     1127     3.0
# 282       3     1129     5.0
# 283       3     1179     3.0
# 284       3     1188     2.0
# 285       3     1193     4.0
# 286       3     1196     5.0
# 287       3     1197     5.0
# 288       3     1198     5.0
# 289       3     1199     4.0
# 290       3     1200     4.0
# 291       3     1206     5.0
# 292       3     1208     5.0
# 293       3     1210     5.0
# 294       3     1213     5.0
# 295       3     1214     5.0
# 296       3     1215     4.0
# 297       3     1219     4.0
# 298       3     1220     5.0
# 299       3     1221     5.0
# 300       3     1222     5.0
# 301       3     1225     3.0
# 302       3     1228     3.0
# 303       3     1230     5.0
# 304       3     1240     5.0
# 305       3     1242     5.0
# 306       3     1247     5.0
# 307       3     1257     5.0
# 308       3     1258     5.0
# 309       3     1259     5.0
# 310       3     1261     5.0
# 311       3     1266     5.0
# 312       3     1270     5.0
# 313       3     1272     4.0
# 314       3     1276     5.0
# 315       3     1278     5.0
# 316       3     1288     2.0
# 317       3     1304     5.0
# 318       3     1307     4.0
# 319       3     1321     5.0
# 320       3     1330     3.0
# 321       3     1333     4.0
# 322       3     1345     4.0
# 323       3     1356     5.0
# 324       3     1372     3.0
# 325       3     1373     4.0
# 326       3     1374     5.0
# 327       3     1375     5.0
# 328       3     1376     4.0
# 329       3     1396     3.0
# 330       3     1544     4.0
# 331       3     1584     4.0
# 332       3     1603     4.0
# 333       3     1653     4.0
# 334       3     1674     4.0
# 335       3     1676     5.0
# 336       3     1721     4.0
# 337       3     1762     4.0
# 338       3     1779     3.0
# 339       3     1810     3.0
# 340       3     1831     5.0
# 341       3     1876     4.0
# 342       3     1882     4.0
# 343       3     1909     5.0
# 344       3     1917     4.0
# 345       3     1921     4.0
# 346       3     2009     5.0
# 347       3     2011     3.0
# 348       3     2012     3.0
# 349       3     2018     4.0
# 350       3     2028     4.0
# 351       3     2034     4.0
# 352       3     2046     5.0
# 353       3     2053     3.0
# 354       3     2054     4.0
# 355       3     2076     5.0
# 356       3     2093     5.0
# 357       3     2105     4.0
# 358       3     2117     5.0
# 359       3     2118     5.0
# 360       3     2140     4.0
# 361       3     2150     5.0
# 362       3     2236     4.0
# 363       3     2288     5.0
# 364       3     2311     4.0
# 365       3     2329     4.0
# 366       3     2366     4.0
# 367       3     2371     4.0
# 368       3     2391     5.0
# 369       3     2407     4.0
# 370       3     2428     4.0
# 371       3     2448     5.0
# 372       3     2455     4.0
# 373       3     2505     4.0
# 374       3     2528     4.0
# 375       3     2529     5.0
# 376       3     2530     4.0
# 377       3     2531     3.0
# 378       3     2532     4.0
# 379       3     2533     3.0
# 380       3     2541     1.0
# 381       3     2551     4.0
# 382       3     2567     3.0
# 383       3     2571     5.0
# 384       3     2574     3.0
# 385       3     2613     4.0
# 386       3     2615     4.0
# 387       3     2628     5.0
# 388       3     2640     4.0
# 389       3     2642     3.0
# 390       3     2643     1.0
# 391       3     2657     3.0
# 392       3     2662     3.0
# 393       3     2668     4.0
# 394       3     2676     1.0
# 395       3     2694     4.0
# 396       3     2699     3.0
# 397       3     2710     5.0
# 398       3     2722     4.0
# 399       3     2750     4.0
# 400       3     2788     5.0
# 401       3     2791     5.0
# 402       3     2797     4.0
# 403       3     2808     4.0
# 404       3     2857     3.0
# 405       3     2872     5.0
# 406       3     2900     3.0
# 407       3     2901     3.0
# 408       3     2916     4.0
# 409       3     2918     5.0
# 410       3     2947     4.0
# 411       3     2948     4.0
# 412       3     2949     4.0
# 413       3     2968     5.0
# 414       3     2985     5.0
# 415       3     2986     2.0
# 416       3     3033     5.0
# 417       3     3039     5.0
# 418       3     3070     4.0
# 419       3     3072     4.0
# 420       3     3098     4.0
# 421       3     3142     4.0
# 422       3     5060     5.0
# 423       4        6     3.0
# 424       4       10     4.0
# 425       4       19     3.0
# 426       4       32     1.0
# 427       4      165     3.0
# 428       4      329     3.0
# 429       4      350     4.0
# 430       4      356     4.0
# 431       4      367     3.0
# 432       4      368     4.0
# 433       4      370     4.0
# 434       4      377     4.0
# 435       4      380     3.0
# 436       4      420     3.0
# 437       4      431     4.0
# 438       4      440     3.0
# 439       4      454     5.0
# 440       4      480     4.0
# 441       4      489     4.0
# 442       4      519     3.0
# 443       4      520     4.0
# 444       4      531     3.0
# 445       4      548     3.0
# 446       4      586     4.0
# 447       4      589     4.0
# 448       4      594     4.0
# 449       4      596     4.0
# 450       4      733     5.0
# 451       5        2     3.0
# 452       5       11     5.0
# 453       5       17     3.0
# 454       5       60     3.0
# 455       5       62     5.0
# 456       5      104     2.0
# 457       5      110     4.0
# 458       5      140     2.0
# 459       5      141     5.0
# 460       5      150     5.0
# 461       5      224     2.0
# 462       5      235     3.0
# 463       5      260     5.0
# 464       5      282     4.0
# 465       5      316     4.0
# 466       5      318     5.0
# 467       5      350     4.0
# 468       5      364     5.0
# 469       5      367     3.0
# 470       5      368     5.0
# 471       5      370     4.0
# 472       5      376     4.0
# 473       5      377     5.0
# 474       5      380     5.0
# 475       5      440     5.0
# 476       5      454     5.0
# 477       5      457     5.0
# 478       5      475     4.0
# 479       5      480     4.0
# 480       5      491     4.0
# 481       5      500     5.0
# 482       5      508     5.0
# 483       5      515     3.0
# 484       5      529     4.0
# 485       5      531     5.0
# 486       5      587     4.0
# 487       5      588     5.0
# 488       5      589     5.0
# 489       5      590     5.0
# 490       5      593     3.0
# 491       5      594     5.0
# 492       5      595     5.0
# 493       5      608     3.0
# 494       5      631     3.0
# 495       5      648     3.0
# 496       5      671     5.0
# 497       5      708     3.0
# 498       5      720     5.0
# 499       5      736     5.0
# 500       5      780     5.0
# 501       5      788     3.0
# 502       5      832     5.0
# 503       5     1028     5.0
# 504       5     1035     5.0
# 505       5     1036     5.0
# 506       5     1042     4.0
# 507       5     1073     2.0
# 508       5     1079     5.0
# 509       5     1080     5.0
# 510       5     1097     5.0
# 511       5     1136     5.0
# 512       5     1196     5.0
# 513       5     1198     5.0
# 514       5     1210     5.0
# 515       5     1291     5.0
# 516       5     1393     5.0
# 517       6        1     5.0
# 518       6        3     3.0
# 519       6        7     5.0
# 520       6       17     5.0
# 521       6       52     5.0
# 522       6       62     5.0
# 523       6      135     3.0
# 524       6      140     4.0
# 525       6      141     5.0
# 526       6      260     4.0
# 527       6      494     4.0
# 528       6      628     4.0
# 529       6      648     5.0
# 530       6      653     4.0
# 531       6      708     4.0
# 532       6      719     3.0
# 533       6      733     3.0
# 534       6      736     2.0
# 535       6      743     3.0
# 536       6      762     3.0
# 537       6      780     3.0
# 538       6      788     4.0
# 539       6      802     3.0
# 540       6     1073     1.0
# 541       7        3     3.0
# 542       7        7     3.0
# 543       7       11     4.0
# 544       7       15     2.0
# 545       7       16     3.0
# 546       7       17     2.0
# 547       7       24     3.0
# 548       7      105     2.0
# 549       7      122     2.0
# 550       7      151     3.0
# 551       7      252     2.0
# 552       7      260     5.0
# 553       7      271     3.0
# 554       7      276     2.0
# 555       7      316     3.0
# 556       7      339     3.0
# 557       7      348     4.0
# 558       7      351     3.0
# 559       7      355     3.0
# 560       7      356     4.0
# 561       7      357     3.0
# 562       7      362     3.0
# 563       7      364     4.0
# 564       7      377     3.0
# 565       7      425     3.0
# 566       7      440     4.0
# 567       7      480     5.0
# 568       7      509     2.0
# 569       7      539     4.0
# 570       7      553     4.0
# 571       7      587     5.0
# 572       7      589     5.0
# 573       7      590     4.0
# 574       7      597     4.0
# 575       7      674     2.0
# 576       7      708     3.0
# 577       7      736     3.0
# 578       7      750     5.0
# 579       7      780     4.0
# 580       7      788     3.0
# 581       7      806     1.0
# 582       7      852     3.0
# 583       7      880     3.0
# 584       7      899     4.0
# 585       7      908     4.0
# 586       7      912     5.0
# 587       7      914     3.0
# 588       7      920     4.0
# 589       7      922     3.0
# 590       7      924     3.0
# 591       7      928     3.0
# 592       7      932     3.0
# 593       7      952     3.0
# 594       7     1017     4.0
# 595       7     1020     3.0
# 596       7     1077     5.0
# 597       7     1094     3.0
# 598       7     1095     1.0
# 599       7     1097     4.0
# 600       7     1101     3.0
# 601       7     1183     3.0
# 602       7     1196     5.0
# 603       7     1206     2.0
# 604       7     1210     5.0
# 605       7     1230     3.0
# 606       7     1247     4.0
# 607       7     1253     4.0
# 608       7     1256     5.0
# 609       7     1259     3.0
# 610       7     1265     4.0
# 611       7     1270     4.0
# 612       7     1271     4.0
# 613       7     1272     4.0
# 614       7     1301     3.0
# 615       7     1307     3.0
# 616       7     1343     3.0
# 617       7     1357     4.0
# 618       7     1385     4.0
# 619       7     1391     2.0
# 620       7     1393     3.0
# 621       7     1408     3.0
# 622       7     1409     2.0
# 623       7     1441     3.0
# 624       7     1449     4.0
# 625       7     1466     3.0
# 626       7     1513     2.0
# 627       7     1517     3.0
# 628       7     1544     4.0
# 629       7     1573     3.0
# 630       7     1580     3.0
# 631       7     1597     3.0
# 632       7     1617     3.0
# 633       7     1674     4.0
# 634       7     1682     2.0
# 635       7     1721     5.0
# 636       7     1777     4.0
# 637       7     1882     3.0
# 638       7     1888     3.0
# 639       7     1894     3.0
# 640       7     1911     4.0
# 641       7     1917     4.0
# 642       7     1932     3.0
# 643       7     1964     3.0
# 644       7     2011     4.0
# 645       7     2012     4.0
# 646       7     2013     3.0
# 647       7     2018     4.0
# 648       7     2028     5.0
# 649       7     2054     3.0
# 650       7     2067     3.0
# 651       7     2080     4.0
# 652       7     2081     3.0
# 653       7     2108     3.0
# 654       7     2112     3.0
# 655       7     2125     3.0
# 656       7     2146     3.0
# 657       7     2195     2.0
# 658       7     2243     3.0
# 659       7     2266     2.0
# 660       7     2297     3.0
# 661       7     2311     3.0
# 662       7     2316     3.0
# 663       7     2333     3.0
# 664       7     2346     3.0
# 665       7     2363     3.0
# 666       7     2367     3.0
# 667       7     2384     3.0
# 668       7     2385     2.0
# 669       7     2390     4.0
# 670       7     2396     3.0
# 671       7     2403     4.0
# 672       7     2405     4.0
# 673       7     2407     4.0
# 674       7     2424     3.0
# 675       7     2427     3.0
# 676       7     2463     4.0
# 677       7     2468     2.0
# 678       7     2469     3.0
# 679       7     2478     2.0
# 680       7     2498     2.0
# 681       7     2529     4.0
# 682       7     2535     3.0
# 683       7     2546     3.0
# 684       7     2558     3.0
# 685       7     2598     3.0
# 686       7     2628     4.0
# 687       7     2633     3.0
# 688       7     2640     4.0
# 689       7     2641     4.0
# 690       7     2642     3.0
# 691       7     2654     4.0
# 692       7     2657     2.0
# 693       7     2664     4.0
# 694       7     2671     4.0
# 695       7     2683     3.0
# 696       7     2694     3.0
# 697       7     2701     3.0
# 698       7     2716     4.0
# 699       7     2722     3.0
# 700       7     2723     3.0
# 701       7     2734     2.0
# 702       7     2752     4.0
# 703       7     2762     5.0
# 704       7     2770     2.0
# 705       7     2858     3.0
# 706       7     2861     3.0
# 707       7     2881     4.0
# 708       7     2908     4.0
# 709       7     2916     3.0
# 710       7     2942     5.0
# 711       7     2950     3.0
# 712       7     2959     4.0
# 713       7     2968     2.0
# 714       7     2987     4.0
# 715       7     2993     4.0
# 716       7     3004     2.0
# 717       7     3032     2.0
# 718       7     3033     2.0
# 719       7     3037     4.0
# 720       7     3039     3.0
# 721       7     3062     3.0
# 722       7     3074     3.0
# 723       7     3081     2.0
# 724       7     3086     4.0
# 725       7     3103     2.0
# 726       7     3108     3.0
# 727       7     3118     3.0
# 728       7     3156     3.0
# 729       7     3175     2.0
# 730       7     3176     2.0
# 731       7     3179     5.0
# 732       7     3185     3.0
# 733       7     3194     4.0
# 734       7     3199     2.0
# 735       7     3219     2.0
# 736       7     3235     3.0
# 737       7     3244     3.0
# 738       7     3334     3.0
# 739       7     3341     4.0
# 740       7     3354     3.0
# 741       7     3363     4.0
# 742       7     3408     4.0
# 743       7     3417     5.0
# 744       7     3448     4.0
# 745       7     3469     4.0
# 746       7     3479     5.0
# 747       7     3501     3.0
# 748       7     3510     4.0
# 749       7     3512     4.0
# 750       7     3524     4.0
# 751       7     3526     3.0
# 752       7     3527     3.0
# 753       7     3528     2.0
# 754       7     3578     5.0
# 755       7     3593     2.0
# 756       7     3671     4.0
# 757       7     3684     3.0
# 758       7     3699     4.0
# 759       7     3701     3.0
# 760       7     3717     2.0
# 761       7     3753     4.0
# 762       7     3754     2.0
# 763       7     3793     4.0
# 764       7     3798     2.0
# 765       7     3824     2.0
# 766       7     3826     4.0
# 767       7     3827     3.0
# 768       7     3844     3.0
# 769       7     3864     3.0
# 770       7     3911     4.0
# 771       7     3926     3.0
# 772       7     3932     4.0
# 773       7     3959     4.0
# 774       7     3977     4.0
# 775       7     3978     3.0
# 776       7     3987     4.0
# 777       7     3988     4.0
# 778       7     3994     3.0
# 779       7     4018     3.0
# 780       7     4019     4.0
# 781       7     4023     3.0
# 782       7     4041     4.0
# 783       7     4062     3.0
# 784       7     4155     3.0
# 785       7     4186     4.0
# 786       7     4270     3.0
# 787       7     4306     5.0
# 788       7     4308     4.0
# 789       7     4310     3.0
# 790       7     4317     3.0
# 791       7     4339     4.0
# 792       7     4349     3.0
# 793       7     4361     3.0
# 794       7     4368     3.0
# 795       7     4370     2.0
# 796       7     4464     2.0
# 797       7     4503     3.0
# 798       7     4545     4.0
# 799       7     4603     2.0
# 800       7     4626     4.0
# 801       7     4638     4.0
# 802       7     4639     2.0
# 803       7     4643     4.0
# 804       7     4661     2.0
# 805       7     4700     3.0
# 806       7     4736     3.0
# 807       7     4799     5.0
# 808       7     4848     1.0
# 809       7     4867     4.0
# 810       7     4874     4.0
# 811       7     4896     3.0
# 812       7     4963     5.0
# 813       7     4993     4.0
# 814       7     4994     4.0
# 815       7     4995     3.0
# 816       7     5009     3.0
# 817       8        1     4.0
# 818       8        3     5.0
# 819       8        6     3.0
# 820       8       10     4.0
# 821       8       19     1.0
# 822       8       21     4.0
# 823       8       39     3.0
# 824       8       47     5.0
# 825       8       48     4.0
# 826       8      110     5.0
# 827       8      150     4.0
# 828       8      153     3.0
# 829       8      161     4.0
# 830       8      165     3.0
# 831       8      168     3.0
# 832       8      172     1.0
# 833       8      173     3.0
# 834       8      185     2.0
# 835       8      207     4.0
# 836       8      208     3.0
# 837       8      231     3.0
# 838       8      236     4.0
# 839       8      253     4.0
# 840       8      266     5.0
# 841       8      276     3.0
# 842       8      277     4.0
# 843       8      288     5.0
# 844       8      292     4.0
# 845       8      296     5.0
# 846       8      316     2.0
# 847       8      329     3.0
# 848       8      338     2.0
# 849       8      339     4.0
# 850       8      344     3.0
# 851       8      349     5.0
# 852       8      350     4.0
# 853       8      353     3.0
# 854       8      355     2.0
# 855       8      356     5.0
# 856       8      357     4.0
# 857       8      364     4.0
# 858       8      367     3.0
# 859       8      372     4.0
# 860       8      377     4.0
# 861       8      380     4.0
# 862       8      381     4.0
# 863       8      434     5.0
# 864       8      442     4.0
# 865       8      454     4.0
# 866       8      457     5.0
# 867       8      480     4.0
# 868       8      500     4.0
# 869       8      508     3.0
# 870       8      527     5.0
# 871       8      539     4.0
# 872       8      550     4.0
# 873       8      551     4.0
# 874       8      552     3.0
# 875       8      553     5.0
# 876       8      587     4.0
# 877       8      588     3.0
# 878       8      589     5.0
# 879       8      590     5.0
# 880       8      592     4.0
# 881       8      593     5.0
# 882       8      595     3.0
# 883       8      597     5.0
# 884       8      610     4.0
# 885       8      648     5.0
# 886       8      733     4.0
# 887       9      356     4.0
# 888       9      858     5.0
# 889       9     1219     3.0
# 890       9     1911     3.0
# 891       9     1923     4.0
# 892       9     1997     5.0
# 893       9     2279     3.0
# 894       9     2605     2.0
# 895       9     2683     3.0
# 896       9     2688     3.0
# 897       9     2706     4.0
# 898       9     2710     3.0
# 899       9     2719     2.0
# 900       9     2722     2.0
# 901       9     2840     3.0
# 902       9     2841     4.0
# 903       9     2959     5.0
# 904       9     3016     2.0
# 905       9     3785     2.0
# 906       9     3798     5.0
# 907       9     3857     3.0
# 908       9     3908     2.0
# 909       9     3979     3.0
# 910       9     3994     3.0
# 911       9     3999     2.0
# 912       9     4022     4.0
# 913       9     4030     2.0
# 914       9     4034     1.0
# 915       9     4148     5.0
# 916       9     4369     4.0
# 917       9     4483     2.0
# 918       9     4502     1.0
# 919       9     4509     3.0
# 920       9     4519     2.0
# 921       9     4533     3.0
# 922      10        1     4.0
# 923      10       11     4.0
# 924      10       25     4.0
# 925      10      260     4.0
# 926      10      356     3.0
# 927      10      527     5.0
# 928      10      858     5.0
# 929      10      912     4.0
# 930      10      969     4.0
# 931      10     1094     3.0
# 932      10     1136     4.0
# 933      10     1196     4.0
# 934      10     1198     4.0
# 935      10     1204     3.0
# 936      10     1208     4.0
# 937      10     1210     4.0
# 938      10     1221     5.0
# 939      10     1222     3.0
# 940      10     1230     4.0
# 941      10     1240     4.0
# 942      10     1242     4.0
# 943      10     1247     5.0
# 944      10     1250     4.0
# 945      10     1304     3.0
# 946      10     1387     5.0
# 947      10     1721     4.0
# 948      10     1960     3.0
# 949      10     2028     4.0
# 950      10     2058     3.0
# 951      10     2194     4.0
# 952      10     2384     4.0
# 953      10     2529     3.0
# 954      10     2657     4.0
# 955      10     2797     4.0
# 956      10     2944     4.0
# 957      10     2948     4.0
# 958      10     3062     4.0
# 959      10     3107     3.0
# 960      11        1     4.5
# 961      11       10     2.5
# 962      11       19     3.5
# 963      11       32     5.0
# 964      11       39     4.5
# 965      11       65     2.0
# 966      11      110     4.0
# 967      11      145     3.0
# 968      11      150     5.0
# 969      11      153     3.5
# 970      11      158     4.0
# 971      11      160     4.0
# 972      11      165     4.0
# 973      11      170     5.0
# 974      11      172     5.0
# 975      11      173     5.0
# 976      11      185     4.0
# 977      11      208     4.5
# 978      11      231     4.0
# 979      11      253     4.5
# 980      11      256     5.0
# 981      11      260     5.0
# 982      11      286     0.5
# 983      11      296     3.5
# 984      11      316     3.5
# 985      11      318     5.0
# 986      11      344     3.5
# 987      11      356     5.0
# 988      11      364     4.0
# 989      11      367     4.0
# 990      11      377     4.0
# 991      11      380     5.0
# 992      11      384     3.5
# 993      11      405     3.5
# 994      11      410     4.0
# 995      11      441     1.5
# 996      11      442     4.5
# 997      11      480     5.0
# 998      11      500     4.5
# 999      11      519     1.0

# %% [markdown]
# ## Part 1: Basic Recommendations
#
# One way to recommend movies is to always recommend the movies with the highest average rating. In this part, we will use Spark to find the name, number of ratings, and the average rating of the 20 movies with the highest average rating and at least 500 reviews. We want to filter our movies with high ratings but greater than or equal to 500 reviews because movies with few reviews may not have broad appeal to everyone.

# %% [markdown]
# ### (1a) Movies with Highest Average Ratings
#
# Let's determine the movies with the highest average ratings.
#
# The steps you should perform are:
#
# 1. Recall that the `ratings_df` contains three columns:
#     - The ID of the user who rated the film
#     - the ID of the movie being rated
#     - and the rating.
#
#    First, transform `ratings_df` into a second DataFrame, `movie_ids_with_avg_ratings_df`, with the following columns:
#     - The movie ID
#     - The number of ratings for the movie
#     - The average of all the movie's ratings
#
#
# 2. Transform `movie_ids_with_avg_ratings_df` to another DataFrame, `movie_names_with_avg_ratings_df` that adds the movie name to each row. `movie_names_with_avg_ratings_df`
#    will contain these columns:
#     - The movie ID
#     - The movie name
#     - The number of ratings for the movie
#     - The average of all the movie's ratings
#
#    **Hint**: You'll need to do a join.
#
# You should end up with something like the following:
# ```
# movie_ids_with_avg_ratings_df:
# +-------+-----+------------------+
# |movieId|count|average           |
# +-------+-----+------------------+
# |1831   |7463 |2.5785207021305103|
# |431    |8946 |3.695059244355019 |
# |631    |2193 |2.7273141814865483|
# +-------+-----+------------------+
# only showing top 3 rows
#
# movie_names_with_avg_ratings_df:
# +-------+-----------------------------+-----+-------+
# |average|title                        |count|movieId|
# +-------+-----------------------------+-----+-------+
# |5.0    |Ella Lola, a la Trilby (1898)|1    |94431  |
# |5.0    |Serving Life (2011)          |1    |129034 |
# |5.0    |Diplomatic Immunity (2009? ) |1    |107434 |
# +-------+-----------------------------+-----+-------+
# only showing top 3 rows
# ```

# %%
# TODO: Replace <FILL_IN> with appropriate code
from pyspark.sql import functions as F

# From ratingsDF, create a movie_ids_with_avg_ratings_df that combines the two DataFrames
movie_ids_with_avg_ratings_df = (ratings_df.groupBy('movieId')
                                 .agg(F.count(ratings_df.rating).alias("count"), 
                                      F.avg(ratings_df.rating).alias("average")))
print ('movie_ids_with_avg_ratings_df:')
movie_ids_with_avg_ratings_df.show(3, truncate=False)

# Note: movie_names_df is a temporary variable, used only to separate the steps necessary
# to create the movie_names_with_avg_ratings_df DataFrame.
movie_names_df = movie_ids_with_avg_ratings_df.join(movies_df,
                                                    movie_ids_with_avg_ratings_df['movieId'] == movies_df['ID']
                                                    ,"inner")
print ('movie_names_df:')
movie_names_df.show(3, truncate=False)

movie_names_with_avg_ratings_df = (movie_names_df.select('average', 'title', 'count', 'movieId')
                                                  .orderBy('movieId', ascending = False))

print ('movie_names_with_avg_ratings_df:')
movie_names_with_avg_ratings_df.show(3, truncate=False)
# Out:
# movie_ids_with_avg_ratings_df:
# +-------+-----+------------------+
# |movieId|count|average           |
# +-------+-----+------------------+
# |3997   |2047 |2.0703468490473864|
# |1580   |35580|3.55831928049466  |
# |3918   |1246 |2.918940609951846 |
# +-------+-----+------------------+
# only showing top 3 rows
#
# movie_names_df:
# +-------+-----+------------------+----+--------------------------------+
# |movieId|count|average           |ID  |title                           |
# +-------+-----+------------------+----+--------------------------------+
# |3997   |2047 |2.0703468490473864|3997|Dungeons & Dragons (2000)       |
# |1580   |35580|3.55831928049466  |1580|Men in Black (a.k.a. MIB) (1997)|
# |3918   |1246 |2.918940609951846 |3918|Hellbound: Hellraiser II (1988) |
# +-------+-----+------------------+----+--------------------------------+
# only showing top 3 rows
#
# movie_names_with_avg_ratings_df:
# +-------+-------------------+-----+-------+
# |average|title              |count|movieId|
# +-------+-------------------+-----+-------+
# |4.0    |Innocence (2014)   |1    |131262 |
# |3.0    |Rentun Ruusu (2001)|1    |131260 |
# |2.5    |The Pirates (2014) |1    |131258 |
# +-------+-------------------+-----+-------+
# only showing top 3 rows

# %%
# TEST Movies with Highest Average Ratings (1a)
testmti850.Test.assertEquals(movie_ids_with_avg_ratings_df.count(), 26744,
                'incorrect movie_ids_with_avg_ratings_df.count() (expected 26744)')
movie_ids_with_ratings_take_ordered = movie_ids_with_avg_ratings_df.orderBy('MovieID').take(3)
_take_0 = movie_ids_with_ratings_take_ordered[0]
_take_1 = movie_ids_with_ratings_take_ordered[1]
_take_2 = movie_ids_with_ratings_take_ordered[2]
testmti850.Test.assertTrue(_take_0[0] == 1 and _take_0[1] == 49695,
                'incorrect count of ratings for movie with ID {0} (expected 49695)'.format(_take_0[0]))
testmti850.Test.assertEquals(round(_take_0[2], 2), 3.92, "Incorrect average for movie ID {0}. Expected 3.92".format(_take_0[0]))

testmti850.Test.assertTrue(_take_1[0] == 2 and _take_1[1] == 22243,
                'incorrect count of ratings for movie with ID {0} (expected 22243)'.format(_take_1[0]))
testmti850.Test.assertEquals(round(_take_1[2], 2), 3.21, "Incorrect average for movie ID {0}. Expected 3.21".format(_take_1[0]))

testmti850.Test.assertTrue(_take_2[0] == 3 and _take_2[1] == 12735,
                'incorrect count of ratings for movie with ID {0} (expected 12735)'.format(_take_2[0]))
testmti850.Test.assertEquals(round(_take_2[2], 2), 3.15, "Incorrect average for movie ID {0}. Expected 3.15".format(_take_2[0]))


testmti850.Test.assertEquals(movie_names_with_avg_ratings_df.count(), 26744,
                  'incorrect movie_names_with_avg_ratings_df.count() (expected 26744)')
movie_names_with_ratings_take_ordered = movie_names_with_avg_ratings_df.orderBy(['average', 'title']).take(3)
result = [(r['average'], r['title'], r['count'], r['movieId']) for r in movie_names_with_ratings_take_ordered]
testmti850.Test.assertEquals(result,
                  [(0.5, u'13 Fighting Men (1960)', 1, 109355),
                   (0.5, u'20 Years After (2008)', 1, 131062),
                   (0.5, u'3 Holiday Tails (Golden Christmas 2: The Second Tail, A) (2011)', 1, 111040)],
                  'incorrect top 3 entries in movie_names_with_avg_ratings_df')
# Out:
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.

# %% [markdown]
# ### (1b) Movies with Highest Average Ratings and at least 500 reviews
#
# Now that we have a DataFrame of the movies with highest average ratings, we can use Spark to determine the 20 movies with highest average ratings and at least 500 reviews.
#
# Add a single DataFrame transformation (in place of `<FILL_IN>`, below) to limit the results to movies with ratings from at least 500 people.

# %%
# TODO: Replace <FILL IN> with appropriate code

movies_with_500_ratings_or_more = movie_names_with_avg_ratings_df.where(movie_names_with_avg_ratings_df['count'] >=500)

print ('Movies with highest ratings:')
movies_with_500_ratings_or_more.show(20, truncate=False)
# Out:
# Movies with highest ratings:
# +------------------+------------------------------------------------+-----+-------+
# |average           |title                                           |count|movieId|
# +------------------+------------------------------------------------+-----+-------+
# |3.413568773234201 |The Hobbit: The Battle of the Five Armies (2014)|538  |118696 |
# |3.445326278659612 |The Hunger Games: Mockingjay - Part 1 (2014)    |567  |116823 |
# |3.9802371541501977|The Imitation Game (2014)                       |759  |116797 |
# |3.865353037766831 |Nightcrawler (2014)                             |609  |115569 |
# |3.854807223035627 |Guardians of the Galaxy (2014)                  |2049 |112852 |
# |3.611989459815547 |Dawn of the Planet of the Apes (2014)           |759  |112623 |
# |3.9364435429344153|Gone Girl (2014)                                |1479 |112556 |
# |4.074750830564784 |Whiplash (2014)                                 |602  |112552 |
# |3.8532311062431543|Boyhood (2014)                                  |913  |112290 |
# |3.824404761904762 |Birdman (2014)                                  |840  |112183 |
# |3.71976401179941  |How to Train Your Dragon 2 (2014)               |678  |112175 |
# |3.482276119402985 |22 Jump Street (2014)                           |536  |112138 |
# |3.8436374549819927|Edge of Tomorrow (2014)                         |1666 |111759 |
# |2.9644160583941606|Godzilla (2014)                                 |548  |111364 |
# |3.823663624511082 |X-Men: Days of Future Past (2014)               |1534 |111362 |
# |3.051470588235294 |Lucy (2014)                                     |544  |111360 |
# |3.201388888888889 |The Amazing Spider-Man 2 (2014)                 |504  |110553 |
# |3.710943695479778 |Captain America: The Winter Soldier (2014)      |1261 |110102 |
# |4.023864289821737 |Interstellar (2014)                             |1739 |109487 |
# |3.992152466367713 |Grand Budapest Hotel, The (2014)                |2230 |109374 |
# +------------------+------------------------------------------------+-----+-------+
# only showing top 20 rows

# %%
# TEST Movies with Highest Average Ratings and at least 500 Reviews (1b)
testmti850.Test.assertEquals(movies_with_500_ratings_or_more.count(), 4489,
                  'incorrect movies_with_500_ratings_or_more.count(). Expected 4489.')
top_20_results = [(r['average'], r['title'], r['count']) for r in movies_with_500_ratings_or_more.orderBy(F.desc('average')).take(20)]

testmti850.Test.assertEquals(top_20_results,
                  [(4.446990499637029, u'Shawshank Redemption, The (1994)', 63366),
                   (4.364732196832306, u'Godfather, The (1972)', 41355),
                   (4.334372207803259, u'Usual Suspects, The (1995)', 47006),
                   (4.310175010988133, u"Schindler's List (1993)", 50054),
                   (4.275640557704942, u'Godfather: Part II, The (1974)', 27398),
                   (4.2741796572216, u'Seven Samurai (Shichinin no samurai) (1954)', 11611),
                   (4.271333600779414, u'Rear Window (1954)', 17449),
                   (4.263182346109176, u'Band of Brothers (2001)', 4305),
                   (4.258326830670664, u'Casablanca (1942)', 24349),
                   (4.256934865900383, u'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', 6525),
                   (4.24807897901911, u"One Flew Over the Cuckoo's Nest (1975)", 29932),
                   (4.247286821705426, u'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 23220),
                   (4.246001523229246, u'Third Man, The (1949)', 6565),
                   (4.235410064157069, u'City of God (Cidade de Deus) (2002)', 12937),
                   (4.2347902097902095, u'Lives of Others, The (Das leben der Anderen) (2006)', 5720),
                   (4.233538107122288, u'North by Northwest (1959)', 15627),
                   (4.2326233183856505, u'Paths of Glory (1957)', 3568),
                   (4.227123123722136, u'Fight Club (1999)', 40106),
                   (4.224281931146873, u'Double Indemnity (1944)', 4909),
                   (4.224137931034483, u'12 Angry Men (1957)', 12934)],
                  'Incorrect top 20 movies with 500 or more ratings')
# Out:
# 1 test passed.
# 1 test passed.

# %% [markdown]
# Using a threshold on the number of reviews is one way to improve the recommendations, but there are many other good ways to improve quality. For example, you could weight ratings by the number of ratings.

# %% [markdown]
# ## Part 2: Collaborative Filtering
# In this course, you have learned about many of the basic transformations and actions that Spark allows us to apply to distributed datasets.  Spark also exposes some higher level functionality; in particular, Machine Learning using a component of Spark called [MLlib][mllib].  In this part, you will learn how to use MLlib to make personalized movie recommendations using the movie data we have been analyzing.
#
# <img src="https://alekoe.github.io/images/Collaborative_filtering.gif" alt="collaborative filtering" style="float: right"/>
#
# We are going to use a technique called [collaborative filtering][collab]. Collaborative filtering is a method of making automatic predictions (filtering) about the interests of a user by collecting preferences or taste information from many users (collaborating). The underlying assumption of the collaborative filtering approach is that if a person A has the same opinion as a person B on an issue, A is more likely to have B's opinion on a different issue 'X' than to have the opinion on 'X' of a person chosen randomly. You can read more about collaborative filtering [here][collab2].
#
# The image at the right (from [Wikipedia][collab]) shows an example of predicting of the user's rating using collaborative filtering. At first, people rate different items (like videos, images, games). After that, the system is making predictions about a user's rating for an item, which the user has not rated yet. These predictions are built upon the existing ratings of other users, who have similar ratings with the active user. For instance, in the image below the system has made a prediction, that the active user will not like the video.
#
# <br clear="all"/>
#
# ----
#
# For movie recommendations, we start with a matrix whose entries are movie ratings by users (shown in red in the diagram below).  Each column represents a user (shown in green) and each row represents a particular movie (shown in blue).
#
# Since not all users have rated all movies, we do not know all of the entries in this matrix, which is precisely why we need collaborative filtering.  For each user, we have ratings for only a subset of the movies.  With collaborative filtering, the idea is to approximate the ratings matrix by factorizing it as the product of two matrices: one that describes properties of each user (shown in green), and one that describes properties of each movie (shown in blue).
#
# <img alt="factorization" src="https://alekoe.github.io/images/matrix_factorization.png" style="width: 885px"/>
# <br clear="all"/>
#
# We want to select these two matrices such that the error for the users/movie pairs where we know the correct ratings is minimized. The [Alternating Least Squares][als] algorithm does this by first randomly filling the users matrix with values and then optimizing the value of the movies such that the error is minimized.  Then, it holds the movies matrix constant and optimizes the value of the user's matrix.  This alternation between which matrix to optimize is the reason for the "alternating" in the name.
#
# This optimization is what's being shown on the right in the image above.  Given a fixed set of user factors (i.e., values in the users matrix), we use the known ratings to find the best values for the movie factors using the optimization written at the bottom of the figure.  Then we "alternate" and pick the best user factors given fixed movie factors.
#
# [als]: https://en.wikiversity.org/wiki/Least-Squares_Method
# [mllib]: http://spark.apache.org/docs/1.6.2/mllib-guide.html
# [collab]: https://en.wikipedia.org/?title=Collaborative_filtering
# [collab2]: http://recommender-systems.org/collaborative-filtering/

# %% [markdown]
# ### (2a) Creating a Training Set
#
# Before we jump into using machine learning, we need to break up the `ratings_df` dataset into three pieces:
# * A training set (DataFrame), which we will use to train models
# * A validation set (DataFrame), which we will use to choose the best model
# * A test set (DataFrame), which we will use for our experiments
#
# To randomly split the dataset into the multiple groups, we can use the pySpark [randomSplit()](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame.randomSplit) transformation. `randomSplit()` takes a set of splits and a seed and returns multiple DataFrames.

# %%
# TODO: Replace <FILL_IN> with the appropriate code (keep the seed.

# We'll hold out 60% for training, 20% of our data for validation, and leave 20% for testing
seed = 1800009193
(split_60_df, split_a_20_df, split_b_20_df) = ratings_df.randomSplit([.6, .2, .2], seed=seed)

# Let's cache these datasets for performance
training_df = split_60_df.cache()
validation_df = split_a_20_df.cache()
test_df = split_b_20_df.cache()

print('Training: {0}, validation: {1}, test: {2}\n'.format(
  training_df.count(), validation_df.count(), test_df.count())
)
training_df.show(3)
validation_df.show(3)
test_df.show(3)
# Out:
# Training: 12002851, validation: 4000457, test: 3996955
#
# +------+-------+------+
# |userId|movieId|rating|
# +------+-------+------+
# |     1|     29|   3.5|
# |     1|    112|   3.5|
# |     1|    151|   4.0|
# +------+-------+------+
# only showing top 3 rows
#
# +------+-------+------+
# |userId|movieId|rating|
# +------+-------+------+
# |     1|     47|   3.5|
# |     1|    253|   4.0|
# |     1|    296|   4.0|
# +------+-------+------+
# only showing top 3 rows
#
# +------+-------+------+
# |userId|movieId|rating|
# +------+-------+------+
# |     1|      2|   3.5|
# |     1|     32|   3.5|
# |     1|     50|   3.5|
# +------+-------+------+
# only showing top 3 rows

# %%
### TEST Creating a Training Set (2a)
testmti850.Test.assertEquals(training_df.count(), 12002851, "Incorrect training_df count. Expected 12001518")
testmti850.Test.assertEquals(validation_df.count(), 4000457, "Incorrect validation_df count. Expected 4003623")
testmti850.Test.assertEquals(test_df.count(), 3996955, "Incorrect test_df count. Expected 3995122")

testmti850.Test.assertEquals(training_df.filter((ratings_df.userId == 1) & (ratings_df.movieId == 5952) & (ratings_df.rating == 5.0)).count(), 1)
testmti850.Test.assertEquals(training_df.filter((ratings_df.userId == 1) & (ratings_df.movieId == 1193) & (ratings_df.rating == 3.5)).count(), 1)
testmti850.Test.assertEquals(training_df.filter((ratings_df.userId == 1) & (ratings_df.movieId == 1196) & (ratings_df.rating == 4.5)).count(), 1)

testmti850.Test.assertEquals(validation_df.filter((ratings_df.userId == 1) & (ratings_df.movieId == 296) & (ratings_df.rating == 4.0)).count(), 1)
testmti850.Test.assertEquals(validation_df.filter((ratings_df.userId == 1) & (ratings_df.movieId == 47) & (ratings_df.rating == 3.5)).count(), 1)
testmti850.Test.assertEquals(validation_df.filter((ratings_df.userId == 1) & (ratings_df.movieId == 653) & (ratings_df.rating == 3.0)).count(), 1)

testmti850.Test.assertEquals(test_df.filter((ratings_df.userId == 1) & (ratings_df.movieId == 8507) & (ratings_df.rating == 5.0)).count(), 1)
testmti850.Test.assertEquals(test_df.filter((ratings_df.userId == 1) & (ratings_df.movieId == 4467) & (ratings_df.rating == 4.0)).count(), 1)
testmti850.Test.assertEquals(test_df.filter((ratings_df.userId == 1) & (ratings_df.movieId == 1304) & (ratings_df.rating == 3.0)).count(), 1)
# Out:
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.

# %% [markdown]
# After splitting the dataset, your training set has about 12 million entries and the validation and test sets each have about 4 million entries. (The exact number of entries in each dataset varies slightly due to the random nature of the `randomSplit()` transformation.)

# %% [markdown]
# ### (2b) Alternating Least Squares
#
# In this part, we will use the Apache Spark ML Pipeline implementation of Alternating Least Squares, [ALS](http://spark.apache.org/docs/1.6.2/api/python/pyspark.ml.html#pyspark.ml.recommendation.ALS). ALS takes a training dataset (DataFrame) and several parameters that control the model creation process. To determine the best values for the parameters, we will use ALS to train several models, and then we will select the best model and use the parameters from that model in the rest of this lab exercise.
#
# The process we will use for determining the best model is as follows:
# 1. Pick a set of model parameters. The most important parameter to model is the *rank*, which is the number of columns in the Users matrix (green in the diagram above) or the number of rows in the Movies matrix (blue in the diagram above). In general, a lower rank will mean higher error on the training dataset, but a high rank may lead to [overfitting](https://en.wikipedia.org/wiki/Overfitting).  We will train models with ranks of 4, 8, and 12 using the `training_df` dataset.
#
# 2. Set the appropriate parameters on the `ALS` object:
#     * The "User" column will be set to the values in our `userId` DataFrame column.
#     * The "Item" column will be set to the values in our `movieId` DataFrame column.
#     * The "Rating" column will be set to the values in our `rating` DataFrame column.
#     * We'll using a regularization parameter of 0.1.
#
#    **Note**: Read the documentation for the [ALS](http://spark.apache.org/docs/1.6.2/api/python/pyspark.ml.html#pyspark.ml.recommendation.ALS) class **carefully**. It will help you accomplish this step.
# 3. Have the ALS output transformation (i.e., the result of [ALS.fit()](http://spark.apache.org/docs/1.6.2/api/python/pyspark.ml.html#pyspark.ml.recommendation.ALS.fit)) produce a _new_ column
#    called "prediction" that contains the predicted value.
#
# 4. Create multiple models using [ALS.fit()](http://spark.apache.org/docs/1.6.2/api/python/pyspark.ml.html#pyspark.ml.recommendation.ALS.fit), one for each of our rank values. We'll fit
#    against the training data set (`training_df`).
#
# 5. For each model, we'll run a prediction against our validation data set (`validation_df`) and check the error.
#
# 6. We'll keep the model with the best error rate.
#
# #### Why are we doing our own cross-validation?
#
# A challenge for collaborative filtering is how to provide ratings to a new user (a user who has not provided *any* ratings at all). Some recommendation systems choose to provide new users with a set of default ratings (e.g., an average value across all ratings), while others choose to provide no ratings for new users. Spark's ALS algorithm yields a NaN (`Not a Number`) value when asked to provide a rating for a new user.
#
# Using the ML Pipeline's [CrossValidator](http://spark.apache.org/docs/1.6.2/api/python/pyspark.ml.html#pyspark.ml.tuning.CrossValidator) with ALS is thus problematic, because cross validation involves dividing the training data into a set of folds (e.g., three sets) and then using those folds for testing and evaluating the parameters during the parameter grid search process. It is likely that some of the folds will contain users that are not in the other folds, and, as a result, ALS produces NaN values for those new users. When the CrossValidator uses the Evaluator (RMSE) to compute an error metric, the RMSE algorithm will return NaN. This will make *all* of the parameters in the parameter grid appear to be equally good (or bad).
#
# You can read the discussion on [Spark JIRA 14489](https://issues.apache.org/jira/browse/SPARK-14489) about this issue. There are proposed workarounds of having ALS provide default values or having RMSE drop NaN values. Both introduce potential issues. We have chosen to have RMSE drop NaN values. While this does not solve the underlying issue of ALS not predicting a value for a new user, it does provide some evaluation value. We manually implement the parameter grid search process using a for loop (below) and remove the NaN values before using RMSE.
#
# For a production application, you would want to consider the tradeoffs in how to handle new users.
#
# **Note**: This cell will likely take a couple of minutes to run.

# %%
# TODO: Replace <FILL IN> with appropriate code
# This step is broken in ML Pipelines: https://issues.apache.org/jira/browse/SPARK-14489
from pyspark.ml.recommendation import ALS

# Let's initialize our ALS learner
als = ALS()

# Now we set the parameters for the method
als.setMaxIter(5)\
   .setSeed(seed)\
   .setRegParam(0.1)\
   .setUserCol('userId')\
   .setItemCol('movieId')\
   .setRatingCol('rating')

# Now let's compute an evaluation metric for our test dataset
from pyspark.ml.evaluation import RegressionEvaluator

# Create an RMSE evaluator using the label and predicted columns
reg_eval = RegressionEvaluator(predictionCol="prediction", labelCol="rating", metricName="rmse")

tolerance = 0.03
ranks = [4, 8, 12]
errors = [0, 0, 0]
models = [0, 0, 0]
err = 0
min_error = float('inf')
best_rank = -1
for rank in ranks:
    # Set the rank here:
    als.setRank(rank)
    # Create the model with these parameters.
    model = als.fit(training_df)
    
    # Run the model to create a prediction. Predict against the validation_df.
    predict_df = model.transform(validation_df)
    
    # Remove NaN values from prediction (due to SPARK-14489)
    predicted_ratings_df = predict_df.filter(predict_df.prediction != float('nan'))

    # Run the previously created RMSE evaluator, reg_eval, on the predicted_ratings_df DataFrame
    error = reg_eval.evaluate(predicted_ratings_df)
    
    errors[err] = error
    models[err] = model
    print ('For rank %s the RMSE is %s' % (rank, error))
    if error < min_error:
        min_error = error
        best_rank = err
    err += 1

als.setRank(ranks[best_rank])
print ('The best model was trained with rank %s' % ranks[best_rank])
my_model = models[best_rank]
# Out:
# For rank 4 the RMSE is 0.8244328012840093
# For rank 8 the RMSE is 0.8172415701409743
# For rank 12 the RMSE is 0.8201926005317784
# The best model was trained with rank 8

# %%
# TEST
testmti850.Test.assertEquals(round(min_error, 2), 0.82, "Unexpected value for best RMSE. Expected rounded value to be 0.81. Got {0}".format(round(min_error, 2)))
testmti850.Test.assertEquals(ranks[best_rank], 8, "Unexpected value for best rank. Expected 12. Got {0}".format(ranks[best_rank]))
testmti850.Test.assertEqualsHashed(als.getItemCol(), "18f0e2357f8829fe809b2d95bc1753000dd925a6", "Incorrect choice of {0} for ALS item column.".format(als.getItemCol()))
testmti850.Test.assertEqualsHashed(als.getUserCol(), "db36668fa9a19fde5c9676518f9e86c17cabf65a", "Incorrect choice of {0} for ALS user column.".format(als.getUserCol()))
testmti850.Test.assertEqualsHashed(als.getRatingCol(), "3c2d687ef032e625aa4a2b1cfca9751d2080322c", "Incorrect choice of {0} for ALS rating column.".format(als.getRatingCol()))
# Out:
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.

# %% [markdown]
# ### (2c) Testing Your Model
#
# So far, we used the `training_df` and `validation_df` datasets to select the best model.  Since we used these two datasets to determine what model is best, we cannot use them to test how good the model is; otherwise, we would be very vulnerable to [overfitting](https://en.wikipedia.org/wiki/Overfitting).  To decide how good our model is, we need to use the `test_df` dataset.  We will use the `best_rank` you determined in part (2b) to create a model for predicting the ratings for the test dataset and then we will compute the RMSE.
#
# The steps you should perform are:
# * Run a prediction, using `my_model` as created above, on the test dataset (`test_df`), producing a new `predict_df` DataFrame.
# * Filter out unwanted NaN values (necessary because of [a bug in Spark](https://issues.apache.org/jira/browse/SPARK-14489)). We've supplied this piece of code for you.
# * Use the previously created RMSE evaluator, `reg_eval` to evaluate the filtered DataFrame.

# %%
# TODO: Replace <FILL_IN> with the appropriate code
# In ML Pipelines, this next step has a bug that produces unwanted NaN values. We
# have to filter them out. See https://issues.apache.org/jira/browse/SPARK-14489
predict_df = my_model.transform(test_df)

# Remove NaN values from prediction (due to SPARK-14489)
predicted_test_df = predict_df.filter(predict_df.prediction != float('nan'))

# Run the previously created RMSE evaluator, reg_eval, on the predicted_test_df DataFrame
test_RMSE = reg_eval.evaluate(predicted_test_df)

print('The model had a RMSE on the test set of {0}'.format(test_RMSE))
# Out:
# The model had a RMSE on the test set of 0.8180131927702128

# %%
# TEST Testing Your Model (2c)
testmti850.Test.assertTrue(abs(test_RMSE - 0.809624038485) < tolerance, 'incorrect test_RMSE: {0:.11f}'.format(test_RMSE))
# Out:
# 1 test passed.

# %% [markdown]
# ### (2d) Comparing Your Model
#
# Looking at the RMSE for the results predicted by the model versus the values in the test set is one way to evalute the quality of our model. Another way to evaluate the model is to evaluate the error from a test set where every rating is the average rating for the training set.
#
# The steps you should perform are:
# * Use the `training_df` to compute the average rating across all movies in that training dataset.
# * Use the average rating that you just determined and the `test_df` to create a DataFrame (`test_for_avg_df`) with a `prediction` column containing the average rating. **HINT**: You'll want to use the `lit()` function,
#   from `pyspark.sql.functions`, available here as `F.lit()`.
# * Use our previously created `reg_eval` object to evaluate the `test_for_avg_df` and calculate the RMSE.

# %%
# TODO: Replace <FILL_IN> with the appropriate code.
# Compute the average rating
avg_rating_df = training_df.select(F.avg('rating'))

# Extract the average rating value. (This is row 0, column 0.)
training_avg_rating = avg_rating_df.collect()[0][0]

print('The average rating for movies in the training set is {0}'.format(training_avg_rating))

# Add a column with the average rating
test_for_avg_df = test_df.withColumn('prediction', F.lit(training_avg_rating))

# Run the previously created RMSE evaluator, reg_eval, on the test_for_avg_df DataFrame
test_avg_RMSE = reg_eval.evaluate(test_for_avg_df)

print("The RMSE on the average set is {0}".format(test_avg_RMSE))
# Out:
# The average rating for movies in the training set is 3.5255293513182826
# The RMSE on the average set is 1.0517429715171942

# %%
# TEST Comparing Your Model (2d)
testmti850.Test.assertTrue(abs(training_avg_rating - 3.52552935131) < 0.000001,
                'incorrect training_avg_rating (expected 3.52552935131): {0:.11f}'.format(training_avg_rating))
testmti850.Test.assertTrue(abs(test_avg_RMSE - 1.05174297151) < 0.000001,
                'incorrect test_avg_RMSE (expected 1.05174297151): {0:.11f}'.format(test_avg_RMSE))
# Out:
# 1 test passed.
# 1 test passed.

# %% [markdown]
# You now have code to predict how users will rate movies!

# %% [markdown]
# ## Part 3: Predictions for Yourself
# The ultimate goal of this lab exercise is to predict what movies to recommend to yourself.  In order to do that, you will first need to add ratings for yourself to the `ratings_df` dataset.

# %%
print ('Most rated movies:')
print ('(average rating, movie name, number of reviews, movie ID)')
movies_with_500_ratings_or_more.orderBy(movies_with_500_ratings_or_more['average'], ascending=False).limit(50).toPandas()
# Out:
# Most rated movies:
# (average rating, movie name, number of reviews, movie ID)
#      average                                              title  count  \
# 0   4.446990                   Shawshank Redemption, The (1994)  63366
# 1   4.364732                              Godfather, The (1972)  41355
# 2   4.334372                         Usual Suspects, The (1995)  47006
# 3   4.310175                            Schindler's List (1993)  50054
# 4   4.275641                     Godfather: Part II, The (1974)  27398
# 5   4.274180        Seven Samurai (Shichinin no samurai) (1954)  11611
# 6   4.271334                                 Rear Window (1954)  17449
# 7   4.263182                            Band of Brothers (2001)   4305
# 8   4.258327                                  Casablanca (1942)  24349
# 9   4.256935      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)   6525
# 10  4.248079             One Flew Over the Cuckoo's Nest (1975)  29932
# 11  4.247287  Dr. Strangelove or: How I Learned to Stop Worr...  23220
# 12  4.246002                              Third Man, The (1949)   6565
# 13  4.235410                City of God (Cidade de Deus) (2002)  12937
# 14  4.234790  Lives of Others, The (Das leben der Anderen) (...   5720
# 15  4.233538                          North by Northwest (1959)  15627
# 16  4.232623                              Paths of Glory (1957)   3568
# 17  4.227123                                  Fight Club (1999)  40106
# 18  4.224282                            Double Indemnity (1944)   4909
# 19  4.224138                                12 Angry Men (1957)  12934
# 20  4.220620                                      Cosmos (1980)    936
# 21  4.220129                            Dark Knight, The (2008)  20438
# 22  4.219009  Raiders of the Lost Ark (Indiana Jones and the...  43295
# 23  4.211717                                     Yojimbo (1961)   3559
# 24  4.207361                              Big Sleep, The (1946)   5529
# 25  4.204103                               All About Eve (1950)   4826
# 26  4.203810  Spirited Away (Sen to Chihiro no kamikakushi) ...  13466
# 27  4.199673                                   Chinatown (1974)  15310
# 28  4.197790                                   Notorious (1946)   4932
# 29  4.197072  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...  24349
# 30  4.193171                                           M (1931)   4232
# 31  4.190672          Star Wars: Episode IV - A New Hope (1977)  54502
# 32  4.188943                       To Kill a Mockingbird (1962)  14769
# 33  4.188202  Star Wars: Episode V - The Empire Strikes Back...  45313
# 34  4.187212                         Maltese Falcon, The (1941)  12144
# 35  4.187186                                 Matrix, The (1999)  51334
# 36  4.184187                               Thin Man, The (1934)   3358
# 37  4.183633                                  Goodfellas (1990)  26406
# 38  4.183022                               Touch of Evil (1958)   4718
# 39  4.182990                                Black Mirror (2011)    582
# 40  4.181068        Wallace & Gromit: The Wrong Trousers (1993)  15022
# 41  4.178547                                     Memento (2000)  30443
# 42  4.177057                   Silence of the Lambs, The (1991)  63299
# 43  4.176732                         Princess Bride, The (1987)  32586
# 44  4.176724                         Rashomon (Rashômon) (1950)   3712
# 45  4.175837         Life Is Beautiful (La Vita è bella) (1997)  18156
# 46  4.174231                                Pulp Fiction (1994)  67310
# 47  4.174146             Monty Python and the Holy Grail (1975)  33024
# 48  4.174123                                 City Lights (1931)   2593
# 49  4.173611                                         Ran (1985)   4824
#
#     movieId
# 0       318
# 1       858
# 2        50
# 3       527
# 4      1221
# 5      2019
# 6       904
# 7      7502
# 8       912
# 9       922
# 10     1193
# 11      750
# 12     1212
# 13     6016
# 14    44555
# 15      908
# 16     1178
# 17     2959
# 18     3435
# 19     1203
# 20    77658
# 21    58559
# 22     1198
# 23     3030
# 24     1284
# 25      926
# 26     5618
# 27     1252
# 28      930
# 29     4973
# 30     1260
# 31      260
# 32     1207
# 33     1196
# 34      913
# 35     2571
# 36      950
# 37     1213
# 38     1248
# 39    94466
# 40     1148
# 41     4226
# 42      593
# 43     1197
# 44     5291
# 45     2324
# 46      296
# 47     1136
# 48     3307
# 49     1217

# %% [markdown]
# The user ID 0 is unassigned, so we will use it for your ratings. We set the variable `my_user_ID` to 0 for you. Next, create a new DataFrame called `my_ratings_df`, with your ratings for at least 10 movie ratings. Each entry should be formatted as `(my_user_id, movieID, rating)`.  As in the original dataset, ratings should be between 1 and 5 (inclusive). If you have not seen at least 10 of these movies, you can increase the parameter passed to `take()` in the above cell until there are 10 movies that you have seen (or you can also guess what your rating would be for movies you have not seen).

# %%
# TODO: Replace <FILL IN> with appropriate code
from pyspark.sql import Row
my_user_id = 0

# Note that the movie IDs are the *last* number on each line.
#A common error was to use the number of ratings as the movie ID.
my_rated_movies = [
     # The format of each line is (my_user_id, movie ID, your rating)
     # For example, to give the movie "Star Wars: Episode IV - A New Hope (1977)" a
     # five rating, you would add the following line:
        (my_user_id, 260, 5),
        (my_user_id, 1196, 3),
        (my_user_id, 1210, 5),
        (my_user_id, 2628, 4),
        (my_user_id, 5378, 5),
        (my_user_id, 1356, 2),
        (my_user_id, 1371, 3),
        (my_user_id, 1372, 3),
        (my_user_id, 1375, 5),
        (my_user_id, 1376, 5)
]

my_ratings_df = spark.createDataFrame(my_rated_movies, ['userId','movieId','rating'])
print ('My movie ratings:')
my_ratings_df.limit(10).toPandas()
# Out:
# My movie ratings:
#    userId  movieId  rating
# 0       0      260       5
# 1       0     1196       3
# 2       0     1210       5
# 3       0     2628       4
# 4       0     5378       5
# 5       0     1356       2
# 6       0     1371       3
# 7       0     1372       3
# 8       0     1375       5
# 9       0     1376       5

# %% [markdown]
# ### (3b) Add Your Movies to Training Dataset
#
# Now that you have ratings for yourself, you need to add your ratings to the `training` dataset so that the model you train will incorporate your preferences.  Spark's [unionAll()](http://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.DataFrame.unionAll) transformation combines two DataFrames; use `unionAll()` to create a new training dataset that includes your ratings and the data in the original training dataset.

# %%
# TODO: Replace <FILL IN> with appropriate code
training_with_my_ratings_df = training_df.unionAll(my_ratings_df)

print ('The training dataset now has %s more entries than the original training dataset' %
       (training_with_my_ratings_df.count() - training_df.count()))
assert (training_with_my_ratings_df.count() - training_df.count()) == my_ratings_df.count()
# Out:
# The training dataset now has 10 more entries than the original training dataset

# %% [markdown]
# ### (3c) Train a Model with Your Ratings
#
# Now, train a model with your ratings added and the parameters you used in in part (2b) and (2c). Mke sure you include **all** of the parameters.
#
# **Note**: This cell will take about 30 seconds to run.

# %%
# TODO: Replace <FILL IN> with appropriate code

# Reset the parameters for the ALS object.
als.setPredictionCol("prediction")\
   .setMaxIter(5)\
   .setSeed(seed)\
   .setRegParam(0.1)\
   .setUserCol('userId')\
   .setItemCol('movieId')\
   .setRatingCol('rating')\
   .setRank(best_rank)

# Create the model with these parameters.
my_ratings_model = als.fit(training_with_my_ratings_df)

# %% [markdown]
# ### (3d) Check RMSE for the New Model with Your Ratings
#
# Compute the RMSE for this new model on the test set.
# * Run your model (the one you just trained) against the test data set in `test_df`.
# * Then, use our previously-computed `reg_eval` object to compute the RMSE of your ratings.

# %%
# TODO: Replace <FILL IN> with appropriate code
my_predict_df = my_ratings_model.transform(test_df)

# Remove NaN values from prediction (due to SPARK-14489)
predicted_test_my_ratings_df = my_predict_df.filter(my_predict_df.prediction != float('nan'))

# Run the previously created RMSE evaluator, reg_eval, on the predicted_test_my_ratings_df DataFrame
test_RMSE_my_ratings = reg_eval.evaluate(predicted_test_my_ratings_df)

print('The model had a RMSE on the test set of {0}'.format(test_RMSE_my_ratings))
# Out:
# The model had a RMSE on the test set of 0.8655322216209475

# %% [markdown]
# ### (3e) Predict Your Ratings
#
# So far, we have only computed the error of the model.  Next, let's predict what ratings you would give to the movies that you did not already provide ratings for.
#
# The steps you should perform are:
# * Filter out the movies you already rated manually. (Use the `my_rated_movie_ids` variable.) Put the results in a new `not_rated_df`.
#
#    **Hint**: The [Column.isin()](http://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.Column.isin)
#    method, as well as the `~` ("not") DataFrame logical operator, may come in handy here. Here's an example of using `isin()`:
#
# ```
#     > df1 = sqlContext.createDataFrame([("Jim", 10), ("Julie", 9), ("Abdul", 20), ("Mireille", 19)], ["name", "age"])
#     > df1.show()
#     +--------+---+
#     |    name|age|
#     +--------+---+
#     |     Jim| 10|
#     |   Julie|  9|
#     |   Abdul| 20|
#     |Mireille| 19|
#     +--------+---+
#
#     > names_to_delete = ["Julie", "Abdul"] # this is just a Python list
#     > df2 = df1.filter(~ df1["name"].isin(names_to_delete)) # "NOT IN"
#     > df2.show()
#     +--------+---+
#     |    name|age|
#     +--------+---+
#     |     Jim| 10|
#     |Mireille| 19|
#     +--------+---+
# ```
#
# * Transform `not_rated_df` into `my_unrated_movies_df` by:
#     - renaming the "ID" column to "movieId"
#     - adding a "userId" column with the value contained in the `my_user_id` variable defined above.
#
# * Create a `predicted_ratings_df` DataFrame by applying `my_ratings_model` to `my_unrated_movies_df`.

# %%
# TODO: Replace <FILL_IN> with the appropriate code

# Create a list of my rated movie IDs
my_rated_movie_ids = [x[1] for x in my_rated_movies]

# Filter out the movies I already rated.
not_rated_df = movies_df.filter(~ movies_df['ID'].isin(my_rated_movie_ids))

# Rename the "ID" column to be "movieId", and add a column with my_user_id as "userId".
my_unrated_movies_df = (not_rated_df.withColumnRenamed('ID', 'movieId')
                                    .withColumn('userId', F.lit(my_user_id)))

# Use my_rating_model to predict ratings for the movies that I did not manually rate.
raw_predicted_ratings_df = my_ratings_model.transform(my_unrated_movies_df)

predicted_ratings_df = raw_predicted_ratings_df.filter(raw_predicted_ratings_df['prediction'] != float('nan'))

# %% [markdown]
# ### (3f) Predict Your Ratings
#
# We have our predicted ratings. Now we can print out the 25 movies with the highest predicted ratings.
#
# The steps you should perform are:
# * Join your `predicted_ratings_df` DataFrame with the `movie_names_with_avg_ratings_df` DataFrame to obtain the ratings counts for each movie.
# * Sort the resulting DataFrame (`predicted_with_counts_df`) by predicted rating (highest ratings first), and remove any ratings with a count of 75 or less.
# * Print the top 25 movies that remain.

# %%
predicted_ratings_df.show()
# Out:
# +-------+--------------------+------+----------+
# |movieId|               title|userId|prediction|
# +-------+--------------------+------+----------+
# |    148|Awfully Big Adven...|     0| 3.2542012|
# |    463|Guilty as Sin (1993)|     0| 3.1507828|
# |    471|Hudsucker Proxy, ...|     0|  4.086384|
# |    496|What Happened Was...|     0| 3.7453094|
# |    833|High School High ...|     0| 3.0188515|
# |   1088|Dirty Dancing (1987)|     0| 3.5697787|
# |   1238|   Local Hero (1983)|     0|  4.411836|
# |   1342|     Candyman (1992)|     0| 3.2978806|
# |   1580|Men in Black (a.k...|     0| 3.9294448|
# |   1591|        Spawn (1997)|     0| 2.9271746|
# |   1645|Devil's Advocate,...|     0| 3.8699744|
# |   1829|  Chinese Box (1997)|     0| 3.4854267|
# |   1959|Out of Africa (1985)|     0| 3.9890122|
# |   2122|Children of the C...|     0| 2.9162242|
# |   2142|American Tail: Fi...|     0| 3.3580904|
# |   2366|    King Kong (1933)|     0|  3.946154|
# |   2659|It Came from Holl...|     0|  3.692742|
# |   2866|Buddy Holly Story...|     0| 4.0183024|
# |   3175| Galaxy Quest (1999)|     0|  3.971149|
# |   3749|Time Regained (Te...|     0| 3.8260763|
# +-------+--------------------+------+----------+
# only showing top 20 rows

# %%
movie_names_with_avg_ratings_df.show()
# Out:
# +-------+--------------------+-----+-------+
# |average|               title|count|movieId|
# +-------+--------------------+-----+-------+
# |    4.0|    Innocence (2014)|    1| 131262|
# |    3.0| Rentun Ruusu (2001)|    1| 131260|
# |    2.5|  The Pirates (2014)|    1| 131258|
# |    4.0|Feuer, Eis & Dose...|    1| 131256|
# |    4.0|Kein Bund für's L...|    1| 131254|
# |    4.0|Forklift Driver K...|    1| 131252|
# |    4.0|No More School (2...|    1| 131250|
# |    4.0|Brother Bear 2 (2...|    1| 131248|
# |    4.0|Werner - Gekotzt ...|    1| 131243|
# |    4.0|Ants in the Pants...|    1| 131241|
# |    4.0|Three Quarter Moo...|    1| 131239|
# |    3.0|What Men Talk Abo...|    1| 131237|
# |    3.5|      Standby (2014)|    1| 131231|
# |    2.5|Dead Rising: Watc...|    1| 131180|
# |    4.5|A Second Chance (...|    1| 131176|
# |    3.5|    Gentlemen (2014)|    1| 131174|
# |    1.0|Closed Curtain (2...|    1| 131172|
# |    3.5|    Parallels (2015)|    1| 131170|
# |    3.5|      Phoenix (2014)|    1| 131168|
# |    4.0|   WWII IN HD (2009)|    1| 131166|
# +-------+--------------------+-----+-------+
# only showing top 20 rows

# %%
# TODO: Replace <FILL_IN> with the appropriate code

predicted_with_counts_df = (predicted_ratings_df.join(movie_names_with_avg_ratings_df,
                                                      predicted_ratings_df['movieId'] == movie_names_with_avg_ratings_df['movieId']
                                                      , 'inner'))

predicted_highest_rated_movies_df = (predicted_with_counts_df.orderBy('prediction', ascending=False)
                                                            .where(predicted_with_counts_df['count'] > 75))


print ('My 25 highest rated movies as predicted (for movies with more than 75 reviews):')
predicted_highest_rated_movies_df.show(25)
predicted_highest_rated_movies_df.limit(10).toPandas()
# Out:
# My 25 highest rated movies as predicted (for movies with more than 75 reviews):
# +-------+--------------------+------+----------+------------------+--------------------+-----+-------+
# |movieId|               title|userId|prediction|           average|               title|count|movieId|
# +-------+--------------------+------+----------+------------------+--------------------+-----+-------+
# |    318|Shawshank Redempt...|     0| 4.8614025| 4.446990499637029|Shawshank Redempt...|63366|    318|
# |    858|Godfather, The (1...|     0|  4.792088| 4.364732196832306|Godfather, The (1...|41355|    858|
# |     50|Usual Suspects, T...|     0|  4.770727| 4.334372207803259|Usual Suspects, T...|47006|     50|
# |   6896|        Shoah (1985)|     0| 4.7580485| 4.027272727272727|        Shoah (1985)|  220|   6896|
# |  26082|Harakiri (Seppuku...|     0| 4.7533383| 4.069010416666667|Harakiri (Seppuku...|  384|  26082|
# |   1178|Paths of Glory (1...|     0|  4.752037|4.2326233183856505|Paths of Glory (1...| 3568|   1178|
# |   2019|Seven Samurai (Sh...|     0|  4.738796|   4.2741796572216|Seven Samurai (Sh...|11611|   2019|
# |   1212|Third Man, The (1...|     0|  4.738296| 4.246001523229246|Third Man, The (1...| 6565|   1212|
# |    922|Sunset Blvd. (a.k...|     0| 4.7363734| 4.256934865900383|Sunset Blvd. (a.k...| 6525|    922|
# |    904|  Rear Window (1954)|     0|  4.734813| 4.271333600779414|  Rear Window (1954)|17449|    904|
# |    527|Schindler's List ...|     0|  4.734682| 4.310175010988133|Schindler's List ...|50054|    527|
# |  44555|Lives of Others, ...|     0|  4.734506|4.2347902097902095|Lives of Others, ...| 5720|  44555|
# | 108583|Fawlty Towers (19...|     0|  4.734377| 4.128260869565217|Fawlty Towers (19...|  230| 108583|
# |   6669|        Ikiru (1952)|     0|  4.731268| 4.124329159212881|        Ikiru (1952)| 1118|   6669|
# |   3134|Grand Illusion (L...|     0|  4.713066| 4.150878293601004|Grand Illusion (L...| 1594|   3134|
# |   3030|      Yojimbo (1961)|     0| 4.7098184| 4.211716774374825|      Yojimbo (1961)| 3559|   3030|
# |   1221|Godfather: Part I...|     0|  4.706632| 4.275640557704942|Godfather: Part I...|27398|   1221|
# |    668|Song of the Littl...|     0| 4.7047796| 4.139947437582129|Song of the Littl...|  761|    668|
# |    912|   Casablanca (1942)|     0| 4.7041297| 4.258326830670664|   Casablanca (1942)|24349|    912|
# |   3435|Double Indemnity ...|     0| 4.7036967| 4.224281931146873|Double Indemnity ...| 4909|   3435|
# |    750|Dr. Strangelove o...|     0|  4.703377| 4.247286821705426|Dr. Strangelove o...|23220|    750|
# |   6643|Tokyo Story (Tôky...|     0| 4.7029366| 4.052334943639291|Tokyo Story (Tôky...|  621|   6643|
# |  32853|Sorrow and the Pi...|     0|  4.702253| 4.038461538461538|Sorrow and the Pi...|  130|  32853|
# |   7767|Best of Youth, Th...|     0| 4.7010684|4.0329411764705885|Best of Youth, Th...|  425|   7767|
# |   6016|City of God (Cida...|     0| 4.6985464| 4.235410064157069|City of God (Cida...|12937|   6016|
# +-------+--------------------+------+----------+------------------+--------------------+-----+-------+
# only showing top 25 rows
#    movieId                                          title  userId  prediction  \
# 0      318               Shawshank Redemption, The (1994)       0    4.861403
# 1      858                          Godfather, The (1972)       0    4.792088
# 2       50                     Usual Suspects, The (1995)       0    4.770727
# 3     6896                                   Shoah (1985)       0    4.758049
# 4    26082                      Harakiri (Seppuku) (1962)       0    4.753338
# 5     1178                          Paths of Glory (1957)       0    4.752037
# 6     2019    Seven Samurai (Shichinin no samurai) (1954)       0    4.738796
# 7     1212                          Third Man, The (1949)       0    4.738296
# 8      922  Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)       0    4.736373
# 9      904                             Rear Window (1954)       0    4.734813
#
#     average                                          title  count  movieId
# 0  4.446990               Shawshank Redemption, The (1994)  63366      318
# 1  4.364732                          Godfather, The (1972)  41355      858
# 2  4.334372                     Usual Suspects, The (1995)  47006       50
# 3  4.027273                                   Shoah (1985)    220     6896
# 4  4.069010                      Harakiri (Seppuku) (1962)    384    26082
# 5  4.232623                          Paths of Glory (1957)   3568     1178
# 6  4.274180    Seven Samurai (Shichinin no samurai) (1954)  11611     2019
# 7  4.246002                          Third Man, The (1949)   6565     1212
# 8  4.256935  Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)   6525      922
# 9  4.271334                             Rear Window (1954)  17449      904

# %%
predicted_highest_rated_movies_df.limit(10).toPandas()
# Out:
#    movieId                                          title  userId  prediction  \
# 0      318               Shawshank Redemption, The (1994)       0    4.861403
# 1      858                          Godfather, The (1972)       0    4.792088
# 2       50                     Usual Suspects, The (1995)       0    4.770727
# 3     6896                                   Shoah (1985)       0    4.758049
# 4    26082                      Harakiri (Seppuku) (1962)       0    4.753338
# 5     1178                          Paths of Glory (1957)       0    4.752037
# 6     2019    Seven Samurai (Shichinin no samurai) (1954)       0    4.738796
# 7     1212                          Third Man, The (1949)       0    4.738296
# 8      922  Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)       0    4.736373
# 9      904                             Rear Window (1954)       0    4.734813
#
#     average                                          title  count  movieId
# 0  4.446990               Shawshank Redemption, The (1994)  63366      318
# 1  4.364732                          Godfather, The (1972)  41355      858
# 2  4.334372                     Usual Suspects, The (1995)  47006       50
# 3  4.027273                                   Shoah (1985)    220     6896
# 4  4.069010                      Harakiri (Seppuku) (1962)    384    26082
# 5  4.232623                          Paths of Glory (1957)   3568     1178
# 6  4.274180    Seven Samurai (Shichinin no samurai) (1954)  11611     2019
# 7  4.246002                          Third Man, The (1949)   6565     1212
# 8  4.256935  Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)   6525      922
# 9  4.271334                             Rear Window (1954)  17449      904

# %% [markdown]
# ### Notebook Ended
